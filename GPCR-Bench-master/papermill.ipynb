# %%
import papermill as pm

# %%
pm.inspect_notebook('gpcr_papermill.ipynb')
# Out:
# {'title_suffix': {'name': 'title_suffix',
#   'inferred_type_name': 'None',
#   'default': '"GPR40"',
#   'help': ''},
#  'file_path_sdf_active': {'name': 'file_path_sdf_active',
#   'inferred_type_name': 'None',
#   'default': '"./GPR40/docking/GPR40_active_docking_lib_sorted.sdf"',
#   'help': ''},
#  'file_path_sdf_decoy': {'name': 'file_path_sdf_decoy',
#   'inferred_type_name': 'None',
#   'default': '"./GPR40/docking/GPR40_decoy_docking_lib_sorted.sdf"',
#   'help': ''},
#  'file_path_strain_active': {'name': 'file_path_strain_active',
#   'inferred_type_name': 'None',
#   'default': '"./GPR40/strain/GPR40_active_docking_lib_sorted.csv"',
#   'help': ''},
#  'file_path_strain_decoy': {'name': 'file_path_strain_decoy',
#   'inferred_type_name': 'None',
#   'default': '"./GPR40/strain/GPR40_decoy_docking_lib_sorted.csv"',
#   'help': ''}}

# %%
# # execute_notebook(<input notebook>, <output notebook>, <dictionary of parameters>)

# pm.execute_notebook(
#     "gpcr_papermill.ipynb",
#     "./papermill/notebooks/gpcr_papermill_output.ipynb",
#     parameters={
#         "title_suffix": "GPR40",
#         "file_path_sdf_active": "./GPR40/docking/GPR40_active_docking_lib_sorted.sdf",
#         "file_path_sdf_decoy": "./GPR40/docking/GPR40_decoy_docking_lib_sorted.sdf",
#         "file_path_strain_active": "./GPR40/strain/GPR40_active_docking_lib_sorted.csv",
#         "file_path_strain_decoy": "./GPR40/strain/GPR40_decoy_docking_lib_sorted.csv",
#     },
# )
# Out:
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:56:53.682552',
#      'end_time': '2024-02-19T21:57:01.800475',
#      'duration': 8.117923,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:56:53.697737Z',
#      'iopub.execute_input': '2024-02-19T21:56:53.698048Z',
#      'iopub.status.idle': '2024-02-19T21:57:01.798566Z',
#      'shell.execute_reply': '2024-02-19T21:57:01.798086Z'}},
#    'outputs': [],
#    'source': 'import pandas as pd\nimport seaborn as sns\nimport numpy as np\nimport matplotlib\nimport matplotlib.pyplot as plt\nimport matplotlib.cm as cm\nfrom sklearn.metrics import roc_curve, auc\nfrom rdkit import Chem\nfrom matplotlib.cm import viridis\nfrom matplotlib.colors import Normalize\n\nmatplotlib.rcdefaults()\nsns.set_style("darkgrid")\nplt.rcParams["figure.dpi"] = 100\n\npd.set_option("display.max_columns", None)',
#    'id': 'd1a8f3ab'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:01.806183',
#      'end_time': '2024-02-19T21:57:01.824812',
#      'duration': 0.018629,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:01.821497Z',
#      'iopub.execute_input': '2024-02-19T21:57:01.821852Z',
#      'iopub.status.idle': '2024-02-19T21:57:01.823839Z',
#      'shell.execute_reply': '2024-02-19T21:57:01.823555Z'}},
#    'outputs': [],
#    'source': '# title suffix\ntitle_suffix = "GPR40"\n\n# Files we are processing\nfile_path_sdf_active = "./GPR40/docking/GPR40_active_docking_lib_sorted.sdf"\nfile_path_sdf_decoy = "./GPR40/docking/GPR40_decoy_docking_lib_sorted.sdf"\nfile_path_strain_active = "./GPR40/strain/GPR40_active_docking_lib_sorted.csv"\nfile_path_strain_decoy = "./GPR40/strain/GPR40_decoy_docking_lib_sorted.csv"',
#    'id': 'd5b0ac88'},
#   {'id': 'fb76f50d',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:01.840145',
#      'end_time': '2024-02-19T21:57:01.856777',
#      'duration': 0.016632,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:01.853796Z',
#      'iopub.execute_input': '2024-02-19T21:57:01.853944Z',
#      'iopub.status.idle': '2024-02-19T21:57:01.855891Z',
#      'shell.execute_reply': '2024-02-19T21:57:01.855625Z'}},
#    'execution_count': 3,
#    'source': '# Parameters\ntitle_suffix = "GPR40"\nfile_path_sdf_active = "./GPR40/docking/GPR40_active_docking_lib_sorted.sdf"\nfile_path_sdf_decoy = "./GPR40/docking/GPR40_decoy_docking_lib_sorted.sdf"\nfile_path_strain_active = "./GPR40/strain/GPR40_active_docking_lib_sorted.csv"\nfile_path_strain_decoy = "./GPR40/strain/GPR40_decoy_docking_lib_sorted.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:01.867854',
#      'end_time': '2024-02-19T21:57:01.880983',
#      'duration': 0.013129,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:01.878541Z',
#      'iopub.execute_input': '2024-02-19T21:57:01.878671Z',
#      'iopub.status.idle': '2024-02-19T21:57:01.880146Z',
#      'shell.execute_reply': '2024-02-19T21:57:01.879912Z'}},
#    'outputs': [],
#    'source': '# import matplotx\n\n# plt.style.use(matplotx.styles.tokyo_night["storm"])',
#    'id': '4dbb7cc7'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:01.891784',
#      'end_time': '2024-02-19T21:57:01.911131',
#      'duration': 0.019347,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:01.904302Z',
#      'iopub.execute_input': '2024-02-19T21:57:01.904510Z',
#      'iopub.status.idle': '2024-02-19T21:57:01.909577Z',
#      'shell.execute_reply': '2024-02-19T21:57:01.909062Z'}},
#    'outputs': [],
#    'source': 'def sdf_to_df(args):\n    """\n    Load molecules and their properties from an SDF file into a DataFrame.\n\n    Example usage: df=sdf_to_df(("./ADRB1/docking/ADRB1_active_docking_lib.sdf", "active"))\n\n    Note that this function was originally intended to be used with the `multiprocessing` module, so the arguments are passed as a tuple.\n\n    Will likely be updated later.\n\n    """\n    file, active_status = args  # Unpack the tuple of arguments\n\n    # Create a molecule supplier\n    mol_supplier = Chem.MultithreadedSDMolSupplier(file, numWriterThreads=8)\n\n    # Load the molecules and their properties into a list\n    molecules = []\n    first_mol = True\n    for mol in mol_supplier:\n        if mol is not None:\n            if first_mol:\n                # Get properties as dictionary only for the first molecule\n                props = mol.GetPropsAsDict()\n                keys = props.keys()\n                first_mol = False\n            else:\n                # For the rest of the molecules, get properties directly\n                props = {key: mol.GetProp(key) for key in keys if mol.HasProp(key)}\n\n            props["Title"] = mol.GetProp("_Name")\n            props["Mol"] = mol\n            props["Activity"] = 1 if active_status == "active" else 0\n            molecules.append(props)\n\n    # Convert the list into a DataFrame\n    df = pd.DataFrame(molecules)\n\n    # Reorder the DataFrame columns\n    cols = ["Title", "Mol", "Activity"] + [\n        col for col in df.columns if col not in ["Title", "Mol", "Activity"]\n    ]\n    df = df[cols]\n    df = df.rename(columns={"Title": "Molecule_Name"})\n\n    # Convert \'r_i_docking_score\' to numeric, coercing errors to NaN\n    df["r_i_docking_score"] = pd.to_numeric(df["r_i_docking_score"], errors="coerce")\n\n    # Print \'Molecule_Name\' and \'r_i_docking_score\' for entries that could not be converted\n    non_convertible_entries = df[df["r_i_docking_score"].isna()]\n    for _, row in non_convertible_entries.iterrows():\n        print(\n            f"Molecule_Name: {row[\'Molecule_Name\']}, r_i_docking_score: {row[\'r_i_docking_score\']}"\n        )\n\n    # Drop rows with non-convertible \'r_i_docking_score\'\n    df = df.dropna(subset=["r_i_docking_score"])\n\n    # Convert \'r_i_docking_score\' to int64\n    df["r_i_docking_score"] = df["r_i_docking_score"].astype("float64")\n\n    return df',
#    'id': '0956170b'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:01.922130',
#      'end_time': '2024-02-19T21:57:02.732476',
#      'duration': 0.810346,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:01.933770Z',
#      'iopub.execute_input': '2024-02-19T21:57:01.933934Z',
#      'iopub.status.idle': '2024-02-19T21:57:02.731249Z',
#      'shell.execute_reply': '2024-02-19T21:57:02.730790Z'}},
#    'outputs': [],
#    'source': 'active_sdf = sdf_to_df((file_path_sdf_active, "active"))\ndecoy_sdf = sdf_to_df((file_path_sdf_decoy, "inactive"))',
#    'id': '9957b45a'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:02.745876',
#      'end_time': '2024-02-19T21:57:02.762866',
#      'duration': 0.01699,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:02.758436Z',
#      'iopub.execute_input': '2024-02-19T21:57:02.758581Z',
#      'iopub.status.idle': '2024-02-19T21:57:02.762041Z',
#      'shell.execute_reply': '2024-02-19T21:57:02.761749Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'False\nFalse\n'}],
#    'source': '#TODO replace with a check for duplicates and sys exit with message\nduplicates_actives = active_sdf["Molecule_Name"].duplicated()\nprint(any(duplicates_actives))\nduplicates_decoys = decoy_sdf["Molecule_Name"].duplicated()\nprint(any(duplicates_decoys))',
#    'id': 'b55ee5b2'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:02.773899',
#      'end_time': '2024-02-19T21:57:02.790627',
#      'duration': 0.016728,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:02.786941Z',
#      'iopub.execute_input': '2024-02-19T21:57:02.787101Z',
#      'iopub.status.idle': '2024-02-19T21:57:02.789739Z',
#      'shell.execute_reply': '2024-02-19T21:57:02.789443Z'}},
#    'outputs': [],
#    'source': '# from old code, probably fine but not optimal\ndef concatenate_csv_files(file_list):\n    """\n    Concatenates multiple strain CSV files into a single dataframe.\n    Only the first five columns are kept for now.\n\n    Args:\n        file_list (list): A list of file paths to the CSV files.\n\n    Returns:\n        pandas.DataFrame: The concatenated dataframe.\n\n    """\n    # Specify the column names\n    column_names = [\n        "Molecule_Name",\n        "Total_E",\n        "Lower_Bound",\n        "Upper_Bound",\n        "Num_Torsion_Patterns",\n    ]\n\n    # List to hold dataframes\n    df_list = []\n\n    # Loop over each file in the list\n    for file in file_list:\n        # Import the CSV file as a df, using only the first five columns of the CSV file\n        df = pd.read_csv(file, usecols=range(5), names=column_names, header=0)\n        df_list.append(df)\n\n    # Concatenate all dataframes in the list\n    final_df = pd.concat(df_list, ignore_index=True)\n\n    return final_df',
#    'id': '45a5d138'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:02.805023',
#      'end_time': '2024-02-19T21:57:02.882833',
#      'duration': 0.07781,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:02.814296Z',
#      'iopub.execute_input': '2024-02-19T21:57:02.814430Z',
#      'iopub.status.idle': '2024-02-19T21:57:02.881559Z',
#      'shell.execute_reply': '2024-02-19T21:57:02.881125Z'}},
#    'outputs': [],
#    'source': 'active_strain = concatenate_csv_files([file_path_strain_active])\ndecoy_strain = concatenate_csv_files([file_path_strain_decoy])',
#    'id': 'aa5290c3'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:02.896408',
#      'end_time': '2024-02-19T21:57:02.911922',
#      'duration': 0.015514,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:02.907487Z',
#      'iopub.execute_input': '2024-02-19T21:57:02.907643Z',
#      'iopub.status.idle': '2024-02-19T21:57:02.911009Z',
#      'shell.execute_reply': '2024-02-19T21:57:02.910605Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'False\nFalse\n'}],
#    'source': '#TODO replace with a check for duplicates and sys exit with message\nduplicates_actives = active_strain["Molecule_Name"].duplicated()\nprint(any(duplicates_actives))\nduplicates_decoys = decoy_strain["Molecule_Name"].duplicated()\nprint(any(duplicates_decoys))',
#    'id': '5c40091d'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:02.925570',
#      'end_time': '2024-02-19T21:57:02.939469',
#      'duration': 0.013899,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:02.936708Z',
#      'iopub.execute_input': '2024-02-19T21:57:02.936841Z',
#      'iopub.status.idle': '2024-02-19T21:57:02.938602Z',
#      'shell.execute_reply': '2024-02-19T21:57:02.938302Z'}},
#    'outputs': [],
#    'source': '# only keep as commented for debug\n# pre_merge = [active_sdf, decoy_sdf, active_strain, decoy_strain]\n\n# for df in pre_merge:\n#     print(df.shape)',
#    'id': 'fe857a0b'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:02.950931',
#      'end_time': '2024-02-19T21:57:02.979098',
#      'duration': 0.028167,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:02.961235Z',
#      'iopub.execute_input': '2024-02-19T21:57:02.961439Z',
#      'iopub.status.idle': '2024-02-19T21:57:02.977613Z',
#      'shell.execute_reply': '2024-02-19T21:57:02.977112Z'}},
#    'outputs': [],
#    'source': "active_data=pd.merge(active_sdf, active_strain, on='Molecule_Name')\ndecoy_data=pd.merge(decoy_sdf, decoy_strain, on='Molecule_Name')",
#    'id': '4331a89a'},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.049465',
#      'end_time': '2024-02-19T21:57:03.061379',
#      'duration': 0.011914,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.058483Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.058664Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.060429Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.060110Z'}},
#    'outputs': [],
#    'source': '# #only keep as commented for debug\n# post_merge = [active_data, decoy_data]\n\n# for df in post_merge:\n#     print(df.shape)',
#    'id': '74e4628d'},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.068273',
#      'end_time': '2024-02-19T21:57:03.082735',
#      'duration': 0.014462,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.074947Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.075084Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.081795Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.081496Z'}},
#    'outputs': [],
#    'source': 'all_data = pd.concat([active_data, decoy_data])\n\n#print(all_data.shape)',
#    'id': 'dd526a57'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.089781',
#      'end_time': '2024-02-19T21:57:03.100344',
#      'duration': 0.010563,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.096604Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.096737Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.099445Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.099124Z'}},
#    'outputs': [],
#    'source': "def plot_density(df, title_suffix):\n  # Hardcoded column names\n  activity_col = 'Activity'\n  score_col = 'r_i_docking_score'\n\n  # Create a density plot for the score of active and inactive molecules\n  sns.kdeplot(df.loc[df[activity_col] == 0, score_col], label='Inactive', fill=True)\n  sns.kdeplot(df.loc[df[activity_col] == 1, score_col], label='Active', fill=True)\n\n  # Add title and labels\n  plt.title(f'Density Plot of Docking Score for Active and Decoy Molecules ({title_suffix})')\n  plt.xlabel('Docking Score')\n  plt.ylabel('Density')\n  plt.legend(loc='best')\n\n  # Show the plot\n  plt.show()",
#    'id': '1089ed2a'},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.106911',
#      'end_time': '2024-02-19T21:57:03.422376',
#      'duration': 0.315465,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.114440Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.114588Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.413197Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.407473Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_density(all_data, title_suffix)',
#    'id': 'c23e5da2'},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.438418',
#      'end_time': '2024-02-19T21:57:03.609150',
#      'duration': 0.170732,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.456002Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.456133Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.602369Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.600818Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'def plot_density_strain(df, title_suffix):\n    # Hardcoded column names\n    activity_col = "Activity"\n    score_col = "Total_E"\n\n    # Create a density plot for the score of active and inactive molecules\n    sns.kdeplot(df.loc[df[activity_col] == 0, score_col], label="Inactive", fill=True)\n    sns.kdeplot(df.loc[df[activity_col] == 1, score_col], label="Active", fill=True)\n\n    # Add title and labels\n    plt.title(\n        f"Density Plot of Strain Energy for Active and Decoy Molecules ({title_suffix})"\n    )\n    plt.xlabel("Total Strain Energy")\n    plt.ylabel("Density")\n    plt.legend(loc="best")\n\n    # Show the plot\n    plt.show()\n\nplot_density_strain(all_data, title_suffix)',
#    'id': '724fce9f'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.701303',
#      'end_time': '2024-02-19T21:57:03.748926',
#      'duration': 0.047623,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.730222Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.731065Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.740127Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.736379Z'}},
#    'outputs': [],
#    'source': 'def calculate_enrichment_parameters(df):\n    """\n    Calculates parameters we will need for Enrichment Plots\n\n    Parameters:\n    df (pandas.DataFrame): The dataframe to calculate the logAUC for.\n\n    Returns:\n    pandas.DataFrame: The dataframe with the logAUC calculated.\n    """\n    # Sort the subset by \'r_i_docking_score\' in ascending order\n\n    df = df.copy()\n\n    df.sort_values(by="r_i_docking_score", inplace=True)\n\n    # Reset the index so that we are ranking by the docking score\n    df.reset_index(drop=True, inplace=True)\n\n    # Adjusting the index to start from 1\n    df.index += 1\n\n    # Calculate the cumulative sum of active compounds\n    df["Cumulative_Actives"] = df["Activity"].cumsum()\n\n    # Calculate the Total Actives\n    df["Total_Actives"] = df["Activity"].sum()\n\n    # Calculate the fraction of identified actives at each row\n    df["Fraction_Actives"] = df["Cumulative_Actives"] / df["Total_Actives"]\n\n    # Calculate the percentage of compounds screened at each row\n    df["Percentage_Screened"] = df.index / len(df)\n\n    return df',
#    'id': '0e8bcff6'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.764387',
#      'end_time': '2024-02-19T21:57:03.811358',
#      'duration': 0.046971,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.774890Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.775010Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.810342Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.809984Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '          Molecule_Name                                            Mol  \\\n1     C03095174_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x29c050e40>   \n2       TAK-875_Isomer2  <rdkit.Chem.rdchem.Mol object at 0x29c0514d0>   \n3     C13171061_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x29c108350>   \n4     C16913079_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x29c1084a0>   \n5     C59503600_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x29c108580>   \n...                 ...                                            ...   \n8784  C05295082_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a8473bc0>   \n8785  C14034419_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a8473c30>   \n8786  C02316442_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a8473ca0>   \n8787  C59109255_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a8473df0>   \n8788  C76819004_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a8473d80>   \n\n      Activity                   s_m_source_file i_m_source_file_index  \\\n1            0   GPR40_chembl19_set_decoy_sc.smi                  8178   \n2            1  GPR40_chembl19_set_active_sc.smi                   246   \n3            0   GPR40_chembl19_set_decoy_sc.smi                  6865   \n4            0   GPR40_chembl19_set_decoy_sc.smi                  6153   \n5            0   GPR40_chembl19_set_decoy_sc.smi                  8204   \n...        ...                               ...                   ...   \n8784         0   GPR40_chembl19_set_decoy_sc.smi                  5936   \n8785         0   GPR40_chembl19_set_decoy_sc.smi                  3471   \n8786         0   GPR40_chembl19_set_decoy_sc.smi                  7644   \n8787         0   GPR40_chembl19_set_decoy_sc.smi                  4612   \n8788         0   GPR40_chembl19_set_decoy_sc.smi                  6091   \n\n     i_lp_mmshare_version i_f3d_flags s_lp_Force_Field r_lp_Energy  \\\n1                   53161           0           S-OPLS     57.1172   \n2                   53161           0           S-OPLS     32.6087   \n3                   53161           0           S-OPLS      21.913   \n4                   53161           0           S-OPLS     58.1713   \n5                   53161           0           S-OPLS     59.0716   \n...                   ...         ...              ...         ...   \n8784                53161           0           S-OPLS     36.4482   \n8785                53161           0           S-OPLS      50.937   \n8786                53161           0           S-OPLS     54.2316   \n8787                53161           0           S-OPLS     55.5781   \n8788                53161           0           S-OPLS     27.9235   \n\n     b_lp_Chiralities_Consistent         s_lp_Variant s_i_glide_gridfile  \\\n1                              1  C03095174_Isomer1-1              GPR40   \n2                              1    TAK-875_Isomer2-1              GPR40   \n3                              1  C13171061_Isomer1-1              GPR40   \n4                              1  C16913079_Isomer1-1              GPR40   \n5                              1  C59503600_Isomer1-1              GPR40   \n...                          ...                  ...                ...   \n8784                           1  C05295082_Isomer1-1              GPR40   \n8785                           1  C14034419_Isomer1-1              GPR40   \n8786                           1  C02316442_Isomer1-1              GPR40   \n8787                           1  C59109255_Isomer1-1              GPR40   \n8788                           1  C76819004_Isomer1-1              GPR40   \n\n     i_i_glide_lignum i_i_glide_rotatable_bonds  r_i_docking_score  \\\n1                8177                         6          -11.17170   \n2                 245                        11          -11.10010   \n3                6864                         4          -10.97510   \n4                6152                         9          -10.87830   \n5                8203       ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Molecule_Name</th>\n      <th>Mol</th>\n      <th>Activity</th>\n      <th>s_m_source_file</th>\n      <th>i_m_source_file_index</th>\n      <th>i_lp_mmshare_version</th>\n      <th>i_f3d_flags</th>\n      <th>s_lp_Force_Field</th>\n      <th>r_lp_Energy</th>\n      <th>b_lp_Chiralities_Consistent</th>\n      <th>s_lp_Variant</th>\n      <th>s_i_glide_gridfile</th>\n      <th>i_i_glide_lignum</th>\n      <th>i_i_glide_rotatable_bonds</th>\n      <th>r_i_docking_score</th>\n      <th>r_i_glide_ligand_efficiency</th>\n      <th>r_i_glide_ligand_efficiency_sa</th>\n      <th>r_i_glide_ligand_efficiency_ln</th>\n      <th>r_i_glide_gscore</th>\n      <th>r_i_glide_lipo</th>\n      <th>r_i_glide_hbond</th>\n      <th>r_i_glide_metal</th>\n      <th>r_i_glide_rewards</th>\n      <th>r_i_glide_evdw</th>\n      <th>r_i_glide_ecoul</th>\n      <th>r_i_glide_erotb</th>\n      <th>r_i_glide_esite</th>\n      <th>r_i_glide_emodel</th>\n      <th>r_i_glide_energy</th>\n      <th>r_i_glide_einternal</th>\n      <th>i_i_glide_confnum</th>\n      <th>i_i_glide_posenum</th>\n      <th>r_i_glide_eff_state_penalty</th>\n      <th>Total_E</th>\n      <th>Lower_Bound</th>\n      <th>Upper_Bound</th>\n      <th>Num_Torsion_Patterns</th>\n      <th>Cumulative_Actives</th>\n      <th>Total_Actives</th>\n      <th>Fraction_Actives</th>\n      <th>Percentage_Screened</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>C03095174_Isomer1</td>\n      <td>&lt;rdkit.Chem.rdchem.Mol object at 0x29c050e40&gt;</td>\n      <td>0</td>\n      <td>GPR40_chembl19_set_decoy_sc.smi</td>\n      <td>8178</td>\n      <td>53161</td>\n      <td>0</td>\n      <td>S-OPLS</td>\n      <td>57.1172</td>\n      <td>1</td>\n      <td>C03095174_Isomer1-1</td>\n      <td>GPR40</td>\n      <td>8177</td>\n      <td>6</td>\n      <td>-11.17170</td>\n      <td>-0.37239</td>\n      <td>-1.1571</td>\n      <td>-2.53833</td>\n      <td>-11.1717</td>\n      <td>-4.5256</td>\n      <td>-0.479901</td>\n      <td>-0</td>\n      <td>-3.22389</td>\n      <td>-45.9457</td>\n      <td>-6.19778</td>\n      <td>0.368657</td>\n      <td>-0.0840014</td>\n      <td>-94.3056</td>\n      <td>-52.1435</td>\n      <td>18.5623</td>\n      <td>126</td>\n      <td>47</td>\n      <td>0</td>\n      <td>11.220968</td>\n      <td>7.912696</td>\n      <td>NaN</td>\n      <td>0.0</td>\n      <td>0</td>\n      <td>244</td>\n      <td>0.000000</td>\n      <td>0.000114</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>TAK-875_Isomer2</td>\n      <td>&lt;rdkit.Chem.rdchem.Mol object at 0x29c0514d0&gt;</td>\n      <td>1</td>\n      <td>GPR40_chembl19_set_active_sc.smi</td>\n      <td>246</td>\n      <td>53161</td>\n      <td>0</td>\n      <td>S-OPLS</td>\n      <td>32.6087</td>\n      <td>1</td>\n      <td>TAK-875_Isomer2-1</td>\n      <td>GPR40</td>\n      <td>245</td>\n      <td>11</td>\n      <td>-11.10010</td>\n      <td>-0.300002</td>\n      <td>-0.999675</td>\n      <td>-2.40735</td>\n      <td>-11.1001</td>\n      <td>-5.53916</td>\n      <td>-0.524851</td>\n      <td>-0</td>\n      <td>-1.01411</td>\n      <td>-46.0319</td>\n      <td>-15.4161</td>\n      <td>0.675266</td>\n      <td>-0.0832139</td>\n      <td>-109.415</td>\n      <td>-61.448</td>\n      <td>11.2322</td>\n      <td>96</td>\n      <td>372</td>\n      <td>0</td>\n      <td>9.807528</td>\n      <td>8.486209</td>\n      <td>NaN</td>\n      <td>3.0</td>\n      <td>1</td>\n      <td>244</td>\n      <td>0.004098</td>\n      <td>0.000228</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>C13171061_Isomer1</td>\n      <td>&lt;rdkit.Chem.rdchem. ...
#      'execution_count': 19}],
#    'source': 'all_data = calculate_enrichment_parameters(all_data)\nall_data',
#    'id': 'e5f26758'},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.824114',
#      'end_time': '2024-02-19T21:57:03.841738',
#      'duration': 0.017624,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.838894Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.839055Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.840903Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.840650Z'}},
#    'outputs': [],
#    'source': 'total_e_thresholds = [None, 4, 4.5, 5.0, 5.5, 6.0, 7.0, 7.5, 8.0]',
#    'id': '69891f6e'},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.855181',
#      'end_time': '2024-02-19T21:57:03.872072',
#      'duration': 0.016891,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.868267Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.868407Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.871242Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.870989Z'}},
#    'outputs': [],
#    'source': 'def logauc_by_strain(df, a=1e-3, total_e_threshold=None):\n    # Filter dataframe based on \'Total_E\' threshold if provided\n    if total_e_threshold is not None:\n        df = df[df["Total_E"] <= total_e_threshold]\n\n    # Invert scores since lower scores indicate positive class\n    y_scores_inverted = -df["r_i_docking_score"]\n\n    # Calculate FPR, TPR, and thresholds using sklearn\n    fpr, tpr, _ = roc_curve(df["Activity"], y_scores_inverted)\n\n    # Select the thresholds that result in FPR >= a for log scale plotting\n    valid_indices = np.where(fpr >= a)\n    fpr_valid = fpr[valid_indices]\n    tpr_valid = tpr[valid_indices]\n\n    # Calculate log of FPR for valid indices\n    log_fpr_valid = np.log10(fpr_valid)\n\n    # Calculate the AUC for the valid range\n    linlog_auc = auc(log_fpr_valid, tpr_valid)\n\n    ### NOTE TIMES 10 NOTE ###\n    log_auc = (linlog_auc / -np.log10(a)) * 10\n\n    return log_auc',
#    'id': 'd9cfdb45'},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.884771',
#      'end_time': '2024-02-19T21:57:03.899294',
#      'duration': 0.014523,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.895717Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.895858Z',
#      'iopub.status.idle': '2024-02-19T21:57:03.898398Z',
#      'shell.execute_reply': '2024-02-19T21:57:03.898153Z'}},
#    'outputs': [],
#    'source': 'def plot_log_aucs(data, thresholds, title_suffix):\n    # Calculate log_auc for each threshold and plot\n    log_aucs = [logauc_by_strain(data, total_e_threshold=t) for t in thresholds]\n    \n    # Create labels for the x-axis\n    x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n    \n    plt.bar(range(len(thresholds)), log_aucs, tick_label=x_labels)\n    plt.title(f"Linear Log10 AUC by Strain Energy Cutoff ({title_suffix})")\n    plt.xlabel("Strain Energy Cutoff")\n    plt.ylabel("Linear Log10 AUC (x10)")\n    plt.show()',
#    'id': '872145e3'},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:03.910225',
#      'end_time': '2024-02-19T21:57:04.023703',
#      'duration': 0.113478,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:03.920335Z',
#      'iopub.execute_input': '2024-02-19T21:57:03.920491Z',
#      'iopub.status.idle': '2024-02-19T21:57:04.022639Z',
#      'shell.execute_reply': '2024-02-19T21:57:04.022235Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_log_aucs(all_data, total_e_thresholds, title_suffix)',
#    'id': '63260216'},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:04.037208',
#      'end_time': '2024-02-19T21:57:04.162232',
#      'duration': 0.125024,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:04.049004Z',
#      'iopub.execute_input': '2024-02-19T21:57:04.049149Z',
#      'iopub.status.idle': '2024-02-19T21:57:04.161129Z',
#      'shell.execute_reply': '2024-02-19T21:57:04.160647Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'def plot_delta_log_aucs(data, thresholds, title_suffix):\n  # Calculate log_auc for \'None\' threshold\n  none_log_auc = logauc_by_strain(data, total_e_threshold=None)\n  \n  # Calculate delta log_auc for each threshold and plot\n  delta_log_aucs = [logauc_by_strain(data, total_e_threshold=t) - none_log_auc for t in thresholds]\n  \n  # Create labels for the x-axis\n  x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n  \n  plt.bar(range(len(thresholds)), delta_log_aucs, tick_label=x_labels)\n  plt.title(f"Delta Linear Log10 AUC by Strain Energy Cutoff ({title_suffix})")\n  plt.xlabel("Strain Energy Cutoff")\n  plt.ylabel("Delta Linear Log10 AUC (x10)")\n  plt.show()\n\nplot_delta_log_aucs(all_data, total_e_thresholds, title_suffix)',
#    'id': 'bfedcadc'},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:04.173522',
#      'end_time': '2024-02-19T21:57:04.222547',
#      'duration': 0.049025,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:04.186280Z',
#      'iopub.execute_input': '2024-02-19T21:57:04.186422Z',
#      'iopub.status.idle': '2024-02-19T21:57:04.221512Z',
#      'shell.execute_reply': '2024-02-19T21:57:04.221221Z'}},
#    'outputs': [],
#    'source': 'def write_log_aucs(data, thresholds, title_suffix):\n    # Calculate log_auc for each threshold\n    log_aucs = [logauc_by_strain(data, total_e_threshold=t) for t in thresholds]\n\n    delta_log_aucs = [0] + [log_aucs[i] - log_aucs[0] for i in range(1, len(log_aucs))]\n\n    #print(f"Delta LogAUCs for {title_suffix}: {delta_log_aucs}")\n\n    # Create labels for the x-axis\n    x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n    \n    # Create a dataframe to hold the data\n    df = pd.DataFrame({\n        "Protein": title_suffix,\n        "Strain Energy Cutoff": x_labels,\n        "Linear Log10 AUC (x10)": log_aucs,\n        "Delta Linear Log10 AUC (x10)": delta_log_aucs\n    })\n    \n    # Write the dataframe to a CSV file\n    df.to_csv(f"strain_log_aucs_{title_suffix}.csv", index=False)\n\nwrite_log_aucs(all_data, total_e_thresholds, title_suffix)',
#    'id': 'dd29b89c'},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:04.235685',
#      'end_time': '2024-02-19T21:57:04.394502',
#      'duration': 0.158817,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:04.248862Z',
#      'iopub.execute_input': '2024-02-19T21:57:04.248991Z',
#      'iopub.status.idle': '2024-02-19T21:57:04.393471Z',
#      'shell.execute_reply': '2024-02-19T21:57:04.393036Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'def enrichment_metrics_by_strain(df, total_e_threshold=None):\n\n    if total_e_threshold is not None:\n        df = df[df["Total_E"] <= total_e_threshold]\n\n    df = calculate_enrichment_parameters(df).copy()\n\n    closest_to_one_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.01).abs().argsort()[:1]\n    ]\n\n    ef1 = (\n        closest_to_one_percent["Cumulative_Actives"].values[0]\n        / closest_to_one_percent["Total_Actives"].values[0]\n    ) * 100\n\n    closest_to_five_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.05).abs().argsort()[:1]\n    ]\n    ef5 = (\n        closest_to_five_percent["Cumulative_Actives"].values[0]\n        / closest_to_five_percent["Total_Actives"].values[0]) * 100\n\n    # print(df.shape)\n\n    # print(\n    #     f"1% Closest Cumulative_Actives: {closest_to_one_percent[\'Cumulative_Actives\'].values[0]}"\n    # )\n    # print(\n    #     f"1% Closest Total_Actives: {closest_to_one_percent[\'Total_Actives\'].values[0]}"\n    # )\n    # print(\n    #     f"5% Closest Cumulative_Actives: {closest_to_five_percent[\'Cumulative_Actives\'].values[0]}"\n    # )\n    # print(\n    #     f"5% Closest Total_Actives: {closest_to_five_percent[\'Total_Actives\'].values[0]}"\n    # )\n\n    return ef1, ef5\n\n\ndef bar_plot_enrichment_by_strain(data, thresholds, title_suffix):\n    # Calculate enrichment for each threshold\n    ef1s, ef5s = zip(*[enrichment_metrics_by_strain(data, total_e_threshold=t) for t in thresholds])\n\n    # print(f"EF1% for {title_suffix}: {ef1s}")\n    # print(f"EF5% for {title_suffix}: {ef5s}")\n\n    # Create labels for the x-axis\n    x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n\n    # Create an array with the positions of each bar on the x axis\n    x = np.arange(len(x_labels))\n\n    # Set the width of the bars\n    bar_width = 0.35\n\n    plt.bar(x - bar_width/2, ef1s, bar_width, label="EF1%")\n    plt.bar(x + bar_width/2, ef5s, bar_width, label="EF5%")\n    plt.title(f"Enrichment Factors by Strain Energy Cutoff ({title_suffix})")\n    plt.xlabel("Strain Energy Cutoff")\n    plt.ylabel("Enrichment Factor (%)")\n    plt.xticks(x, x_labels)  # Set the position and labels of the xticks\n    plt.legend()\n    plt.show()\n\nbar_plot_enrichment_by_strain(all_data, total_e_thresholds, title_suffix)',
#    'id': '5c1c6626'},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:04.405504',
#      'end_time': '2024-02-19T21:57:04.733933',
#      'duration': 0.328429,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:04.440461Z',
#      'iopub.execute_input': '2024-02-19T21:57:04.440606Z',
#      'iopub.status.idle': '2024-02-19T21:57:04.732716Z',
#      'shell.execute_reply': '2024-02-19T21:57:04.732349Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': '/var/folders/2c/b9b_8fbs13j5zcz4wv9bqqjm0000gn/T/ipykernel_45296/2506411786.py:53: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.\n  cmap = cm.get_cmap(\n'},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 800x800 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'def plot_enrichment_curve_by_strain(df, total_e_threshold=None, ax=None, color=\'blue\'):\n\n    if total_e_threshold is not None:\n        df = df[df["Total_E"] <= total_e_threshold]\n\n    df = calculate_enrichment_parameters(df).copy()\n\n    enrichment_auc = auc(df["Percentage_Screened"], df["Fraction_Actives"])\n\n    closest_to_one_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.01).abs().argsort()[:1]\n    ]\n\n    ef1 = (\n        closest_to_one_percent["Cumulative_Actives"].values[0]\n        / closest_to_one_percent["Total_Actives"].values[0]\n    ) * 100\n\n    closest_to_five_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.05).abs().argsort()[:1]\n    ]\n    ef5 = (\n        closest_to_five_percent["Cumulative_Actives"].values[0]\n        / closest_to_five_percent["Total_Actives"].values[0]\n    ) * 100\n\n    # Plot the enrichment curve\n    ax.plot(\n        df["Percentage_Screened"] * 100,\n        df["Fraction_Actives"] * 100,\n        label="Threshold: {}\\nEnrichment AUC = {:.2f}\\n(EF1% = {:.1f}%)\\n(EF5% = {:.0f}%)".format(\n            total_e_threshold if total_e_threshold is not None else \'N/A\',\n            enrichment_auc, ef1, ef5\n            ),\n        color=color\n        )\n\n    # # Add axis labels and title\n    # plt.xlabel("Compounds Screened (%)")\n    # plt.ylabel("Percent of Identified Actives (%)")\n    # plt.title(f"Enrichment Curve ({title_suffix})")\n\n    ax.legend()\n\n\ndef plot_enrichment_all_thresholds(data, thresholds, title_suffix):\n    # Create a single plot\n    fig, ax = plt.subplots(\n        figsize=(8, 8)\n        )\n\n    # Define a colormap\n    cmap = cm.get_cmap(\n        "viridis", len(thresholds) - 1\n    )  # Subtract 1 because the first color is manually set\n\n    # Plot semi-log ROC curve for each threshold\n    for i, t in enumerate(thresholds):\n        # Filter dataframe based on \'Total_E\' threshold\n        df_filtered = data if t is None else data[data["Total_E"] <= t]\n\n        # Set a distinct color for the first threshold\n        color = (\n            "red" if t is None else cmap(i - 1)\n        )  # Subtract 1 because the first color is manually set\n\n        # Call the function with the filtered data\n        plot_enrichment_curve_by_strain(df_filtered, total_e_threshold=t, ax=ax, color=color)\n\n    ax.set_title(f"Enrichment Curves by Strain Energy Thresholds ({title_suffix})")\n    ax.set_xlabel("Percent Screened")\n    ax.set_ylabel("Percent Identified Actives")\n\n    plt.tight_layout()\n    plt.show()\n\nplot = plot_enrichment_all_thresholds(all_data, total_e_thresholds, title_suffix)',
#    'id': '19e9e008'},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:04.752207',
#      'end_time': '2024-02-19T21:57:04.825414',
#      'duration': 0.073207,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:04.763887Z',
#      'iopub.execute_input': '2024-02-19T21:57:04.764011Z',
#      'iopub.status.idle': '2024-02-19T21:57:04.824311Z',
#      'shell.execute_reply': '2024-02-19T21:57:04.824043Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Writing CSV to strain_enrichment_metrics_GPR40.csv\nCSV writing complete.\nCSV writing complete.\n'}],
#    'source': 'def write_enrichment_metrics(data, thresholds, title_suffix):\n    # Calculate enrichment for each threshold\n    ef1s, ef5s = zip(*[enrichment_metrics_by_strain(data, total_e_threshold=t) for t in thresholds])\n\n    # Create labels for the x-axis\n    x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n\n    # Create a dataframe to hold the data\n    df = pd.DataFrame({\n        "Protein": title_suffix,\n        "Strain Energy Cutoff": x_labels,\n        "EF1%": ef1s,\n        "EF5%": ef5s\n    })\n\n    print(f"Writing CSV to strain_enrichment_metrics_{title_suffix}.csv")\n    df.to_csv(f"./papermill/csv/strain_enrichment_metrics_{title_suffix}.csv", index=False)\n    print("CSV writing complete.")\n\n    try:\n        df.to_csv(f"strain_enrichment_metrics_{title_suffix}.csv", index=False)\n        print("CSV writing complete.")\n    except Exception as e:\n        print(f"Failed to write CSV: {e}")\n\nwrite_enrichment_metrics(all_data, total_e_thresholds, title_suffix)',
#    'id': '9488e72e'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:04.838619',
#      'end_time': '2024-02-19T21:57:04.854396',
#      'duration': 0.015777,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:04.850302Z',
#      'iopub.execute_input': '2024-02-19T21:57:04.850440Z',
#      'iopub.status.idle': '2024-02-19T21:57:04.853480Z',
#      'shell.execute_reply': '2024-02-19T21:57:04.853136Z'}},
#    'outputs': [],
#    'source': 'def plot_semi_log_roc(df, a=1e-3, total_e_threshold=None, ax=None, color=\'blue\'):\n  # Filter dataframe based on \'Total_E\' threshold if provided\n  if total_e_threshold is not None:\n    df = df[df["Total_E"] <= total_e_threshold]\n\n  # Invert scores since lower scores indicate positive class\n  y_scores_inverted = -df["r_i_docking_score"]\n\n  # Calculate FPR, TPR, and thresholds using sklearn\n  fpr, tpr, _ = roc_curve(df["Activity"], y_scores_inverted)\n\n  # Select the thresholds that result in FPR >= a for log scale plotting\n  valid_indices = np.where(fpr >= a)\n  fpr_valid = fpr[valid_indices]\n  tpr_valid = tpr[valid_indices]\n\n  # Calculate log of FPR for valid indices\n  log_fpr_valid = np.log10(fpr_valid)\n\n  # Calculate LogAUC\n  log_auc = (auc(log_fpr_valid, tpr_valid) / -np.log10(a)) * 10\n\n  # Count the number of rows with Activity = 1 and the total number of rows\n  activity_1_count = df[df["Activity"] == 1].shape[0]\n  total_count = df.shape[0]\n\n  # Plot semi-log ROC curve\n  ax.plot(\n    log_fpr_valid,\n    tpr_valid,\n    label=f"Threshold: {total_e_threshold if total_e_threshold is not None else \'N/A\'}, LogAUC: {log_auc:.2f}, Actives: {activity_1_count}, Total count: {total_count}",\n    color=color\n  )\n  ax.legend()\n',
#    'id': '00cd5f41'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:04.868033',
#      'end_time': '2024-02-19T21:57:04.886911',
#      'duration': 0.018878,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:04.882549Z',
#      'iopub.execute_input': '2024-02-19T21:57:04.882709Z',
#      'iopub.status.idle': '2024-02-19T21:57:04.885944Z',
#      'shell.execute_reply': '2024-02-19T21:57:04.885432Z'}},
#    'outputs': [],
#    'source': 'def plot_all_thresholds(data, thresholds, title_suffix):\n    # Create a single plot\n    fig, ax = plt.subplots(figsize=(10, 10))\n\n    # Define a colormap\n    cmap = cm.get_cmap(\'viridis\', len(thresholds) - 1)  # Subtract 1 because the first color is manually set\n\n    # Plot semi-log ROC curve for each threshold\n    for i, t in enumerate(thresholds):\n        # Filter dataframe based on \'Total_E\' threshold\n        df_filtered = data if t is None else data[data["Total_E"] <= t]\n\n        # Set a distinct color for the first threshold\n        color = \'red\' if t is None else cmap(i - 1)  # Subtract 1 because the first color is manually set\n\n        # Call the function with the filtered data\n        plot_semi_log_roc(df_filtered, total_e_threshold=t, ax=ax, color=color)\n\n    ax.set_title(f"Strain Energy Thresholds ({title_suffix})")\n    ax.set_xlabel("log(FPR)")\n    ax.set_ylabel("TPR")\n\n    plt.tight_layout()\n    plt.show()',
#    'id': '0c4c47ec'},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:04.902702',
#      'end_time': '2024-02-19T21:57:05.147679',
#      'duration': 0.244977,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:04.919764Z',
#      'iopub.execute_input': '2024-02-19T21:57:04.919934Z',
#      'iopub.status.idle': '2024-02-19T21:57:05.146588Z',
#      'shell.execute_reply': '2024-02-19T21:57:05.146185Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
# ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Molecule_Name</th>\n      <th>Mol</th>\n      <th>Activity</th>\n      <th>s_m_source_file</th>\n      <th>i_m_source_file_index</th>\n      <th>i_lp_mmshare_version</th>\n      <th>i_f3d_flags</th>\n      <th>s_lp_Force_Field</th>\n      <th>r_lp_Energy</th>\n      <th>b_lp_Chiralities_Consistent</th>\n      <th>s_lp_Variant</th>\n      <th>s_i_glide_gridfile</th>\n      <th>i_i_glide_lignum</th>\n      <th>i_i_glide_rotatable_bonds</th>\n      <th>r_i_docking_score</th>\n      <th>r_i_glide_ligand_efficiency</th>\n      <th>r_i_glide_ligand_efficiency_sa</th>\n      <th>r_i_glide_ligand_efficiency_ln</th>\n      <th>r_i_glide_gscore</th>\n      <th>r_i_glide_lipo</th>\n      <th>r_i_glide_hbond</th>\n      <th>r_i_glide_metal</th>\n      <th>r_i_glide_rewards</th>\n      <th>r_i_glide_evdw</th>\n      <th>r_i_glide_ecoul</th>\n      <th>r_i_glide_erotb</th>\n      <th>r_i_glide_esite</th>\n      <th>r_i_glide_emodel</th>\n      <th>r_i_glide_energy</th>\n      <th>r_i_glide_einternal</th>\n      <th>i_i_glide_confnum</th>\n      <th>i_i_glide_posenum</th>\n      <th>r_i_glide_eff_state_penalty</th>\n      <th>Total_E</th>\n      <th>Lower_Bound</th>\n      <th>Upper_Bound</th>\n      <th>Num_Torsion_Patterns</th>\n      <th>Cumulative_Actives</th>\n      <th>Total_Actives</th>\n      <th>Fraction_Actives</th>\n      <th>Percentage_Screened</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>C03095174_Isomer1</td>\n      <td>&lt;rdkit.Chem.rdchem.Mol object at 0x29c050e40&gt;</td>\n      <td>0</td>\n      <td>GPR40_chembl19_set_decoy_sc.smi</td>\n      <td>8178</td>\n      <td>53161</td>\n      <td>0</td>\n      <td>S-OPLS</td>\n      <td>57.1172</td>\n      <td>1</td>\n      <td>C03095174_Isomer1-1</td>\n      <td>GPR40</td>\n      <td>8177</td>\n      <td>6</td>\n      <td>-11.17170</td>\n      <td>-0.37239</td>\n      <td>-1.1571</td>\n      <td>-2.53833</td>\n      <td>-11.1717</td>\n      <td>-4.5256</td>\n      <td>-0.479901</td>\n      <td>-0</td>\n      <td>-3.22389</td>\n      <td>-45.9457</td>\n      <td>-6.19778</td>\n      <td>0.368657</td>\n      <td>-0.0840014</td>\n      <td>-94.3056</td>\n      <td>-52.1435</td>\n      <td>18.5623</td>\n      <td>126</td>\n      <td>47</td>\n      <td>0</td>\n      <td>11.220968</td>\n      <td>7.912696</td>\n      <td>NaN</td>\n      <td>0.0</td>\n      <td>0</td>\n      <td>244</td>\n      <td>0.000000</td>\n      <td>0.000114</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>TAK-875_Isomer2</td>\n      <td>&lt;rdkit.Chem.rdchem.Mol object at 0x29c0514d0&gt;</td>\n      <td>1</td>\n      <td>GPR40_chembl19_set_active_sc.smi</td>\n      <td>246</td>\n      <td>53161</td>\n      <td>0</td>\n      <td>S-OPLS</td>\n      <td>32.6087</td>\n      <td>1</td>\n      <td>TAK-875_Isomer2-1</td>\n      <td>GPR40</td>\n      <td>245</td>\n      <td>11</td>\n      <td>-11.10010</td>\n      <td>-0.300002</td>\n      <td>-0.999675</td>\n      <td>-2.40735</td>\n      <td>-11.1001</td>\n      <td>-5.53916</td>\n      <td>-0.524851</td>\n      <td>-0</td>\n      <td>-1.01411</td>\n      <td>-46.0319</td>\n      <td>-15.4161</td>\n      <td>0.675266</td>\n      <td>-0.0832139</td>\n      <td>-109.415</td>\n      <td>-61.448</td>\n      <td>11.2322</td>\n      <td>96</td>\n      <td>372</td>\n      <td>0</td>\n      <td>9.807528</td>\n      <td>8.486209</td>\n      <td>NaN</td>\n      <td>3.0</td>\n      <td>1</td>\n      <td>244</td>\n      <td>0.004098</td>\n      <td>0.000228</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>C13171061_Isomer1</td>\n      <td>&lt;rdkit.Chem.rdchem. ...
#    'source': 'all_pareto_ranks_indices = np.concatenate(pareto_ranks_indices)\ndisplay(data.iloc[all_pareto_ranks_indices])',
#    'id': '0dec4c60'},
#   {'cell_type': 'code',
#    'execution_count': 45,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:33.176672',
#      'end_time': '2024-02-19T21:57:33.207995',
#      'duration': 0.031323,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:33.204123Z',
#      'iopub.execute_input': '2024-02-19T21:57:33.204299Z',
#      'iopub.status.idle': '2024-02-19T21:57:33.207009Z',
#      'shell.execute_reply': '2024-02-19T21:57:33.206729Z'}},
#    'outputs': [],
#    'source': 'pareto_front_df = data.iloc[all_pareto_ranks_indices]',
#    'id': '61db81f5'},
#   {'cell_type': 'code',
#    'execution_count': 46,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:33.223515',
#      'end_time': '2024-02-19T21:57:33.440311',
#      'duration': 0.216796,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:33.239198Z',
#      'iopub.execute_input': '2024-02-19T21:57:33.239343Z',
#      'iopub.status.idle': '2024-02-19T21:57:33.438396Z',
#      'shell.execute_reply': '2024-02-19T21:57:33.434881Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_density(pareto_front_df, title_suffix)',
#    'id': '1f2811c5'},
#   {'cell_type': 'code',
#    'execution_count': 47,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:33.465377',
#      'end_time': '2024-02-19T21:57:33.667706',
#      'duration': 0.202329,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:33.515079Z',
#      'iopub.execute_input': '2024-02-19T21:57:33.516879Z',
#      'iopub.status.idle': '2024-02-19T21:57:33.665805Z',
#      'shell.execute_reply': '2024-02-19T21:57:33.665268Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_density_strain(pareto_front_df, title_suffix)',
#    'id': 'd0441113'},
#   {'cell_type': 'code',
#    'execution_count': 48,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:33.704997',
#      'end_time': '2024-02-19T21:57:33.750331',
#      'duration': 0.045334,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:33.737226Z',
#      'iopub.execute_input': '2024-02-19T21:57:33.737978Z',
#      'shell.execute_reply': '2024-02-19T21:57:33.746712Z',
#      'iopub.status.idle': '2024-02-19T21:57:33.747609Z'}},
#    'outputs': [],
#    'source': 'pareto_front_df = calculate_enrichment_parameters(pareto_front_df)',
#    'id': '6054ede4'},
#   {'cell_type': 'code',
#    'execution_count': 49,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:33.776245',
#      'end_time': '2024-02-19T21:57:33.811686',
#      'duration': 0.035441,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:33.796830Z',
#      'iopub.execute_input': '2024-02-19T21:57:33.797317Z',
#      'shell.execute_reply': '2024-02-19T21:57:33.806400Z',
#      'iopub.status.idle': '2024-02-19T21:57:33.807540Z'}},
#    'outputs': [],
#    'source': 'def plot_enrichment_curve_classifier(df, title_suffix):\n    """\n    Plots the enrichment curve for a dataframe, including the performance of a random classifier.\n\n    Parameters:\n    df (pandas.DataFrame): The dataframe to plot the enrichment curve for.\n    title_suffix (str): The suffix to add to the title of the plot.\n\n    Returns:\n    None\n    """\n    # Calculate the Enrichment AUC\n    enrichment_auc = auc(df["Percentage_Screened"], df["Fraction_Actives"])\n\n    # Calculate the enrichment at the closest value to 1%\n    # Subtract 0.01 (1%) from the \'Percentage_Screened\' column and find the absolute value\n    # (df[\'Percentage_Screened\'] - 0.01).abs()\n    # Sort the resulting series and take the first index (smallest difference)\n    # (df[\'Percentage_Screened\'] - 0.01).abs().argsort()[:1]\n    # Use the index to get the row from the dataframe\n    closest_to_one_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.01).abs().argsort()[:1]\n    ]\n    # df["Some_Column"].values[0] gets the value of the first row of "Some_Column"\n    # It would return a pd.Series without: .values[0]\n    enrichment_at_one_percent = (\n        closest_to_one_percent["Cumulative_Actives"].values[0]\n        / closest_to_one_percent["Total_Actives"].values[0]\n    )\n\n    closest_to_five_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.05).abs().argsort()[:1]\n    ]\n    # df["Some_Column"].values[0] gets the value of the first row of "Some_Column"\n    # It would return a pd.Series without: .values[0]\n    enrichment_at_five_percent = (\n        closest_to_five_percent["Cumulative_Actives"].values[0]\n        / closest_to_five_percent["Total_Actives"].values[0]\n    )\n\n    # Plot the enrichment curve\n    plt.plot(\n        df["Percentage_Screened"] * 100,\n        df["Fraction_Actives"] * 100,\n        label="Enrichment AUC = {:.2f}\\n(EF1% = {:.1f}%)\\n(EF5% = {:.0f}%)".format(\n            enrichment_auc,\n            enrichment_at_one_percent * 100,\n            enrichment_at_five_percent * 100,\n        ),\n    )\n\n    #   # Plot the enrichment at 1%\n    #   plt.scatter(\n    #   1,\n    #   enrichment_at_one_percent * 100,\n    #   s=0,\n    #   color=\'black\',\n    #   label="Enrichment (%) at 1% = {:.2f}".format(enrichment_at_one_percent*100),\n    # )\n\n    # Calculate and plot the performance of a random classifier\n    overall_fraction_actives = df["Fraction_Actives"].iloc[\n        -1\n    ]  # Assuming the last point represents the overall fraction\n    plt.plot(\n        [0, 100],\n        [0, overall_fraction_actives * 100],\n        label="Random Classifier",\n        linestyle="--",\n        color="grey",\n    )\n\n    # Add axis labels and title\n    plt.xlabel("Compounds Screened (%)")\n    plt.ylabel("Percent of Identified Actives (%)")\n    plt.title(f"Enrichment Curve ({title_suffix})")\n\n    plt.legend()\n    plt.show()\n',
#    'id': 'ea1ce2a5'},
#   {'cell_type': 'code',
#    'execution_count': 50,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:33.829746',
#      'end_time': '2024-02-19T21:57:33.872149',
#      'duration': 0.042403,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:33.864272Z',
#      'iopub.execute_input': '2024-02-19T21:57:33.864457Z',
#      'iopub.status.idle': '2024-02-19T21:57:33.870971Z',
#      'shell.execute_reply': '2024-02-19T21:57:33.870694Z'}},
#    'outputs': [],
#    'source': 'threshold4 = all_data[all_data["Total_E"] <= 4]\nthreshold4 = calculate_enrichment_parameters(threshold4)',
#    'id': 'a5f551cf'},
#   {'cell_type': 'code',
#    'execution_count': 51,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:33.886054',
#      'end_time': '2024-02-19T21:57:34.198210',
#      'duration': 0.312156,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T21:57:33.902513Z',
#      'iopub.execute_input': '2024-02-19T21:57:33.902649Z',
#      'iopub.status.idle': '2024-02-19T21:57:34.197209Z',
#      'shell.execute_reply': '2024-02-19T21:57:34.196837Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_enrichment_curve_classifier(all_data, "GPR40 Baseline")\nplot_enrichment_curve_classifier(threshold4, "GPR40 Total_E <= 4")\nplot_enrichment_curve_classifier(pareto_front_df, "GPR40 Pareto Rank 20")',
#    'id': '8bbfee53'},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T21:57:34.210240',
#      'end_time': '2024-02-19T21:57:34.224608',
#      'duration': 0.014368,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '',
#    'id': 'bdb08a5d'}],
#  'metadata': {'kernelspec': {'display_name': 'analytics_env',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.5',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {'title_suffix': 'GPR40',
#     'file_path_sdf_active': './GPR40/docking/GPR40_active_docking_lib_sorted.sdf',
#     'file_path_sdf_decoy': './GPR40/docking/GPR40_decoy_docking_lib_sorted.sdf',
#     'file_path_strain_active': './GPR40/strain/GPR40_active_docking_lib_sorted.csv',
#     'file_path_strain_decoy': './GPR40/strain/GPR40_decoy_docking_lib_sorted.csv'},
#    'environment_variables': {},
#    'version': '2.5.0',
#    'input_path': 'gpcr_papermill.ipynb',
#    'output_path': 'gpcr_papermill_output.ipynb',
#    'start_time': '2024-02-19T21:56:47.908150',
#    'end_time': '2024-02-19T21:57:34.864736',
#    'duration': 46.956586,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
# parameters = {
#     "title_suffix": "GPR40",
#     "file_path_sdf_active": "./GPR40/docking/GPR40_active_docking_lib_sorted.sdf",
#     "file_path_sdf_decoy": "./GPR40/docking/GPR40_decoy_docking_lib_sorted.sdf",
#     "file_path_strain_active": "./GPR40/strain/GPR40_active_docking_lib_sorted.csv",
#     "file_path_strain_decoy": "./GPR40/strain/GPR40_decoy_docking_lib_sorted.csv",
# }

# output_notebook = (
#     f"./papermill/notebooks/gpcr_papermill_output_{parameters['title_suffix']}.ipynb"
# )

# pm.execute_notebook(
#     "gpcr_papermill.ipynb",
#     output_notebook,
#     parameters=parameters,
# )
# Out:
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:35.827296',
#      'end_time': '2024-02-19T22:17:43.639098',
#      'duration': 7.811802,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:35.839022Z',
#      'iopub.execute_input': '2024-02-19T22:17:35.839412Z',
#      'iopub.status.idle': '2024-02-19T22:17:43.637736Z',
#      'shell.execute_reply': '2024-02-19T22:17:43.637297Z'}},
#    'outputs': [],
#    'source': 'import pandas as pd\nimport seaborn as sns\nimport numpy as np\nimport matplotlib\nimport matplotlib.pyplot as plt\nimport matplotlib.cm as cm\nfrom sklearn.metrics import roc_curve, auc\nfrom rdkit import Chem\nfrom matplotlib.cm import viridis\nfrom matplotlib.colors import Normalize\n\nmatplotlib.rcdefaults()\nsns.set_style("darkgrid")\nplt.rcParams["figure.dpi"] = 100\n\npd.set_option("display.max_columns", None)',
#    'id': '3ac2050a'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:43.644098',
#      'end_time': '2024-02-19T22:17:43.660308',
#      'duration': 0.01621,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:43.656774Z',
#      'iopub.execute_input': '2024-02-19T22:17:43.656994Z',
#      'iopub.status.idle': '2024-02-19T22:17:43.659160Z',
#      'shell.execute_reply': '2024-02-19T22:17:43.658815Z'}},
#    'outputs': [],
#    'source': '# title suffix\ntitle_suffix = "GPR40"\n\n# Files we are processing\nfile_path_sdf_active = "./GPR40/docking/GPR40_active_docking_lib_sorted.sdf"\nfile_path_sdf_decoy = "./GPR40/docking/GPR40_decoy_docking_lib_sorted.sdf"\nfile_path_strain_active = "./GPR40/strain/GPR40_active_docking_lib_sorted.csv"\nfile_path_strain_decoy = "./GPR40/strain/GPR40_decoy_docking_lib_sorted.csv"',
#    'id': 'fdae33f2'},
#   {'id': '317bcb9f',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:43.669436',
#      'end_time': '2024-02-19T22:17:43.684672',
#      'duration': 0.015236,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:43.681720Z',
#      'iopub.execute_input': '2024-02-19T22:17:43.681881Z',
#      'iopub.status.idle': '2024-02-19T22:17:43.683781Z',
#      'shell.execute_reply': '2024-02-19T22:17:43.683440Z'}},
#    'execution_count': 3,
#    'source': '# Parameters\ntitle_suffix = "GPR40"\nfile_path_sdf_active = "./GPR40/docking/GPR40_active_docking_lib_sorted.sdf"\nfile_path_sdf_decoy = "./GPR40/docking/GPR40_decoy_docking_lib_sorted.sdf"\nfile_path_strain_active = "./GPR40/strain/GPR40_active_docking_lib_sorted.csv"\nfile_path_strain_decoy = "./GPR40/strain/GPR40_decoy_docking_lib_sorted.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:43.695523',
#      'end_time': '2024-02-19T22:17:43.709996',
#      'duration': 0.014473,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:43.707169Z',
#      'iopub.execute_input': '2024-02-19T22:17:43.707304Z',
#      'iopub.status.idle': '2024-02-19T22:17:43.708941Z',
#      'shell.execute_reply': '2024-02-19T22:17:43.708563Z'}},
#    'outputs': [],
#    'source': '# import matplotx\n\n# plt.style.use(matplotx.styles.tokyo_night["storm"])',
#    'id': 'fe7e9128'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:43.719944',
#      'end_time': '2024-02-19T22:17:43.738333',
#      'duration': 0.018389,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:43.732779Z',
#      'iopub.execute_input': '2024-02-19T22:17:43.732933Z',
#      'iopub.status.idle': '2024-02-19T22:17:43.737479Z',
#      'shell.execute_reply': '2024-02-19T22:17:43.737201Z'}},
#    'outputs': [],
#    'source': 'def sdf_to_df(args):\n    """\n    Load molecules and their properties from an SDF file into a DataFrame.\n\n    Example usage: df=sdf_to_df(("./ADRB1/docking/ADRB1_active_docking_lib.sdf", "active"))\n\n    Note that this function was originally intended to be used with the `multiprocessing` module, so the arguments are passed as a tuple.\n\n    Will likely be updated later.\n\n    """\n    file, active_status = args  # Unpack the tuple of arguments\n\n    # Create a molecule supplier\n    mol_supplier = Chem.MultithreadedSDMolSupplier(file, numWriterThreads=8)\n\n    # Load the molecules and their properties into a list\n    molecules = []\n    first_mol = True\n    for mol in mol_supplier:\n        if mol is not None:\n            if first_mol:\n                # Get properties as dictionary only for the first molecule\n                props = mol.GetPropsAsDict()\n                keys = props.keys()\n                first_mol = False\n            else:\n                # For the rest of the molecules, get properties directly\n                props = {key: mol.GetProp(key) for key in keys if mol.HasProp(key)}\n\n            props["Title"] = mol.GetProp("_Name")\n            props["Mol"] = mol\n            props["Activity"] = 1 if active_status == "active" else 0\n            molecules.append(props)\n\n    # Convert the list into a DataFrame\n    df = pd.DataFrame(molecules)\n\n    # Reorder the DataFrame columns\n    cols = ["Title", "Mol", "Activity"] + [\n        col for col in df.columns if col not in ["Title", "Mol", "Activity"]\n    ]\n    df = df[cols]\n    df = df.rename(columns={"Title": "Molecule_Name"})\n\n    # Convert \'r_i_docking_score\' to numeric, coercing errors to NaN\n    df["r_i_docking_score"] = pd.to_numeric(df["r_i_docking_score"], errors="coerce")\n\n    # Print \'Molecule_Name\' and \'r_i_docking_score\' for entries that could not be converted\n    non_convertible_entries = df[df["r_i_docking_score"].isna()]\n    for _, row in non_convertible_entries.iterrows():\n        print(\n            f"Molecule_Name: {row[\'Molecule_Name\']}, r_i_docking_score: {row[\'r_i_docking_score\']}"\n        )\n\n    # Drop rows with non-convertible \'r_i_docking_score\'\n    df = df.dropna(subset=["r_i_docking_score"])\n\n    # Convert \'r_i_docking_score\' to int64\n    df["r_i_docking_score"] = df["r_i_docking_score"].astype("float64")\n\n    return df',
#    'id': '8dd8f216'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:43.750051',
#      'end_time': '2024-02-19T22:17:44.510179',
#      'duration': 0.760128,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:43.761130Z',
#      'iopub.execute_input': '2024-02-19T22:17:43.761312Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.508902Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.508506Z'}},
#    'outputs': [],
#    'source': 'active_sdf = sdf_to_df((file_path_sdf_active, "active"))\ndecoy_sdf = sdf_to_df((file_path_sdf_decoy, "inactive"))',
#    'id': '84dce833'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.514624',
#      'end_time': '2024-02-19T22:17:44.526492',
#      'duration': 0.011868,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.522287Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.522423Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.525622Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.525266Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'False\nFalse\n'}],
#    'source': '#TODO replace with a check for duplicates and sys exit with message\nduplicates_actives = active_sdf["Molecule_Name"].duplicated()\nprint(any(duplicates_actives))\nduplicates_decoys = decoy_sdf["Molecule_Name"].duplicated()\nprint(any(duplicates_decoys))',
#    'id': '485fd9b6'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.533553',
#      'end_time': '2024-02-19T22:17:44.543626',
#      'duration': 0.010073,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.540155Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.540287Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.542735Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.542458Z'}},
#    'outputs': [],
#    'source': '# from old code, probably fine but not optimal\ndef concatenate_csv_files(file_list):\n    """\n    Concatenates multiple strain CSV files into a single dataframe.\n    Only the first five columns are kept for now.\n\n    Args:\n        file_list (list): A list of file paths to the CSV files.\n\n    Returns:\n        pandas.DataFrame: The concatenated dataframe.\n\n    """\n    # Specify the column names\n    column_names = [\n        "Molecule_Name",\n        "Total_E",\n        "Lower_Bound",\n        "Upper_Bound",\n        "Num_Torsion_Patterns",\n    ]\n\n    # List to hold dataframes\n    df_list = []\n\n    # Loop over each file in the list\n    for file in file_list:\n        # Import the CSV file as a df, using only the first five columns of the CSV file\n        df = pd.read_csv(file, usecols=range(5), names=column_names, header=0)\n        df_list.append(df)\n\n    # Concatenate all dataframes in the list\n    final_df = pd.concat(df_list, ignore_index=True)\n\n    return final_df',
#    'id': '89bb27cd'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.549296',
#      'end_time': '2024-02-19T22:17:44.605192',
#      'duration': 0.055896,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.555609Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.555715Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.603961Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.603567Z'}},
#    'outputs': [],
#    'source': 'active_strain = concatenate_csv_files([file_path_strain_active])\ndecoy_strain = concatenate_csv_files([file_path_strain_decoy])',
#    'id': '5232a344'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.612149',
#      'end_time': '2024-02-19T22:17:44.625643',
#      'duration': 0.013494,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.621371Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.621510Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.624708Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.624182Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'False\nFalse\n'}],
#    'source': '#TODO replace with a check for duplicates and sys exit with message\nduplicates_actives = active_strain["Molecule_Name"].duplicated()\nprint(any(duplicates_actives))\nduplicates_decoys = decoy_strain["Molecule_Name"].duplicated()\nprint(any(duplicates_decoys))',
#    'id': 'cfd89e7d'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.632389',
#      'end_time': '2024-02-19T22:17:44.641488',
#      'duration': 0.009099,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.638899Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.639026Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.640519Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.640248Z'}},
#    'outputs': [],
#    'source': '# only keep as commented for debug\n# pre_merge = [active_sdf, decoy_sdf, active_strain, decoy_strain]\n\n# for df in pre_merge:\n#     print(df.shape)',
#    'id': '6586240b'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.647821',
#      'end_time': '2024-02-19T22:17:44.664765',
#      'duration': 0.016944,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.654418Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.654543Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.663816Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.663548Z'}},
#    'outputs': [],
#    'source': "active_data=pd.merge(active_sdf, active_strain, on='Molecule_Name')\ndecoy_data=pd.merge(decoy_sdf, decoy_strain, on='Molecule_Name')",
#    'id': '347a99d8'},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.671876',
#      'end_time': '2024-02-19T22:17:44.685113',
#      'duration': 0.013237,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.682666Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.682782Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.684279Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.684009Z'}},
#    'outputs': [],
#    'source': '# #only keep as commented for debug\n# post_merge = [active_data, decoy_data]\n\n# for df in post_merge:\n#     print(df.shape)',
#    'id': '6c53d049'},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.694225',
#      'end_time': '2024-02-19T22:17:44.710808',
#      'duration': 0.016583,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.703533Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.703645Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.709880Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.709516Z'}},
#    'outputs': [],
#    'source': 'all_data = pd.concat([active_data, decoy_data])\n\n#print(all_data.shape)',
#    'id': 'a1e99bbb'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.720975',
#      'end_time': '2024-02-19T22:17:44.736410',
#      'duration': 0.015435,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.732537Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.732687Z',
#      'iopub.status.idle': '2024-02-19T22:17:44.735404Z',
#      'shell.execute_reply': '2024-02-19T22:17:44.735127Z'}},
#    'outputs': [],
#    'source': "def plot_density(df, title_suffix):\n  # Hardcoded column names\n  activity_col = 'Activity'\n  score_col = 'r_i_docking_score'\n\n  # Create a density plot for the score of active and inactive molecules\n  sns.kdeplot(df.loc[df[activity_col] == 0, score_col], label='Inactive', fill=True)\n  sns.kdeplot(df.loc[df[activity_col] == 1, score_col], label='Active', fill=True)\n\n  # Add title and labels\n  plt.title(f'Density Plot of Docking Score for Active and Decoy Molecules ({title_suffix})')\n  plt.xlabel('Docking Score')\n  plt.ylabel('Density')\n  plt.legend(loc='best')\n\n  # Show the plot\n  plt.show()",
#    'id': '588f5f0e'},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:44.747221',
#      'end_time': '2024-02-19T22:17:45.109388',
#      'duration': 0.362167,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:44.756129Z',
#      'iopub.execute_input': '2024-02-19T22:17:44.756251Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.108231Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.107770Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_density(all_data, title_suffix)',
#    'id': 'a275bdee'},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.116314',
#      'end_time': '2024-02-19T22:17:45.277176',
#      'duration': 0.160862,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.123185Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.123324Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.270607Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.262647Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'def plot_density_strain(df, title_suffix):\n    # Hardcoded column names\n    activity_col = "Activity"\n    score_col = "Total_E"\n\n    # Create a density plot for the score of active and inactive molecules\n    sns.kdeplot(df.loc[df[activity_col] == 0, score_col], label="Inactive", fill=True)\n    sns.kdeplot(df.loc[df[activity_col] == 1, score_col], label="Active", fill=True)\n\n    # Add title and labels\n    plt.title(\n        f"Density Plot of Strain Energy for Active and Decoy Molecules ({title_suffix})"\n    )\n    plt.xlabel("Total Strain Energy")\n    plt.ylabel("Density")\n    plt.legend(loc="best")\n\n    # Show the plot\n    plt.show()\n\nplot_density_strain(all_data, title_suffix)',
#    'id': '84f4f728'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.299788',
#      'end_time': '2024-02-19T22:17:45.342346',
#      'duration': 0.042558,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.318384Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.318501Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.334260Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.326542Z'}},
#    'outputs': [],
#    'source': 'def calculate_enrichment_parameters(df):\n    """\n    Calculates parameters we will need for Enrichment Plots\n\n    Parameters:\n    df (pandas.DataFrame): The dataframe to calculate the logAUC for.\n\n    Returns:\n    pandas.DataFrame: The dataframe with the logAUC calculated.\n    """\n    # Sort the subset by \'r_i_docking_score\' in ascending order\n\n    df = df.copy()\n\n    df.sort_values(by="r_i_docking_score", inplace=True)\n\n    # Reset the index so that we are ranking by the docking score\n    df.reset_index(drop=True, inplace=True)\n\n    # Adjusting the index to start from 1\n    df.index += 1\n\n    # Calculate the cumulative sum of active compounds\n    df["Cumulative_Actives"] = df["Activity"].cumsum()\n\n    # Calculate the Total Actives\n    df["Total_Actives"] = df["Activity"].sum()\n\n    # Calculate the fraction of identified actives at each row\n    df["Fraction_Actives"] = df["Cumulative_Actives"] / df["Total_Actives"]\n\n    # Calculate the percentage of compounds screened at each row\n    df["Percentage_Screened"] = df.index / len(df)\n\n    return df',
#    'id': '6550aa3d'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.357273',
#      'end_time': '2024-02-19T22:17:45.426389',
#      'duration': 0.069116,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.385040Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.386374Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.425376Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.425057Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '          Molecule_Name                                            Mol  \\\n1     C03095174_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x15b7cc430>   \n2       TAK-875_Isomer2  <rdkit.Chem.rdchem.Mol object at 0x15b714e40>   \n3     C13171061_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x15b7cc2e0>   \n4     C16913079_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x15b7cc510>   \n5     C59503600_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x15b7cc3c0>   \n...                 ...                                            ...   \n8784  C05295082_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a3b73bc0>   \n8785  C14034419_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a3b73d10>   \n8786  C02316442_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a3b73ca0>   \n8787  C59109255_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a3b73df0>   \n8788  C76819004_Isomer1  <rdkit.Chem.rdchem.Mol object at 0x2a3b73d80>   \n\n      Activity                   s_m_source_file i_m_source_file_index  \\\n1            0   GPR40_chembl19_set_decoy_sc.smi                  8178   \n2            1  GPR40_chembl19_set_active_sc.smi                   246   \n3            0   GPR40_chembl19_set_decoy_sc.smi                  6865   \n4            0   GPR40_chembl19_set_decoy_sc.smi                  6153   \n5            0   GPR40_chembl19_set_decoy_sc.smi                  8204   \n...        ...                               ...                   ...   \n8784         0   GPR40_chembl19_set_decoy_sc.smi                  5936   \n8785         0   GPR40_chembl19_set_decoy_sc.smi                  3471   \n8786         0   GPR40_chembl19_set_decoy_sc.smi                  7644   \n8787         0   GPR40_chembl19_set_decoy_sc.smi                  4612   \n8788         0   GPR40_chembl19_set_decoy_sc.smi                  6091   \n\n     i_lp_mmshare_version i_f3d_flags s_lp_Force_Field r_lp_Energy  \\\n1                   53161           0           S-OPLS     57.1172   \n2                   53161           0           S-OPLS     32.6087   \n3                   53161           0           S-OPLS      21.913   \n4                   53161           0           S-OPLS     58.1713   \n5                   53161           0           S-OPLS     59.0716   \n...                   ...         ...              ...         ...   \n8784                53161           0           S-OPLS     36.4482   \n8785                53161           0           S-OPLS      50.937   \n8786                53161           0           S-OPLS     54.2316   \n8787                53161           0           S-OPLS     55.5781   \n8788                53161           0           S-OPLS     27.9235   \n\n     b_lp_Chiralities_Consistent         s_lp_Variant s_i_glide_gridfile  \\\n1                              1  C03095174_Isomer1-1              GPR40   \n2                              1    TAK-875_Isomer2-1              GPR40   \n3                              1  C13171061_Isomer1-1              GPR40   \n4                              1  C16913079_Isomer1-1              GPR40   \n5                              1  C59503600_Isomer1-1              GPR40   \n...                          ...                  ...                ...   \n8784                           1  C05295082_Isomer1-1              GPR40   \n8785                           1  C14034419_Isomer1-1              GPR40   \n8786                           1  C02316442_Isomer1-1              GPR40   \n8787                           1  C59109255_Isomer1-1              GPR40   \n8788                           1  C76819004_Isomer1-1              GPR40   \n\n     i_i_glide_lignum i_i_glide_rotatable_bonds  r_i_docking_score  \\\n1                8177                         6          -11.17170   \n2                 245                        11          -11.10010   \n3                6864                         4          -10.97510   \n4                6152                         9          -10.87830   \n5                8203       ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Molecule_Name</th>\n      <th>Mol</th>\n      <th>Activity</th>\n      <th>s_m_source_file</th>\n      <th>i_m_source_file_index</th>\n      <th>i_lp_mmshare_version</th>\n      <th>i_f3d_flags</th>\n      <th>s_lp_Force_Field</th>\n      <th>r_lp_Energy</th>\n      <th>b_lp_Chiralities_Consistent</th>\n      <th>s_lp_Variant</th>\n      <th>s_i_glide_gridfile</th>\n      <th>i_i_glide_lignum</th>\n      <th>i_i_glide_rotatable_bonds</th>\n      <th>r_i_docking_score</th>\n      <th>r_i_glide_ligand_efficiency</th>\n      <th>r_i_glide_ligand_efficiency_sa</th>\n      <th>r_i_glide_ligand_efficiency_ln</th>\n      <th>r_i_glide_gscore</th>\n      <th>r_i_glide_lipo</th>\n      <th>r_i_glide_hbond</th>\n      <th>r_i_glide_metal</th>\n      <th>r_i_glide_rewards</th>\n      <th>r_i_glide_evdw</th>\n      <th>r_i_glide_ecoul</th>\n      <th>r_i_glide_erotb</th>\n      <th>r_i_glide_esite</th>\n      <th>r_i_glide_emodel</th>\n      <th>r_i_glide_energy</th>\n      <th>r_i_glide_einternal</th>\n      <th>i_i_glide_confnum</th>\n      <th>i_i_glide_posenum</th>\n      <th>r_i_glide_eff_state_penalty</th>\n      <th>Total_E</th>\n      <th>Lower_Bound</th>\n      <th>Upper_Bound</th>\n      <th>Num_Torsion_Patterns</th>\n      <th>Cumulative_Actives</th>\n      <th>Total_Actives</th>\n      <th>Fraction_Actives</th>\n      <th>Percentage_Screened</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>C03095174_Isomer1</td>\n      <td>&lt;rdkit.Chem.rdchem.Mol object at 0x15b7cc430&gt;</td>\n      <td>0</td>\n      <td>GPR40_chembl19_set_decoy_sc.smi</td>\n      <td>8178</td>\n      <td>53161</td>\n      <td>0</td>\n      <td>S-OPLS</td>\n      <td>57.1172</td>\n      <td>1</td>\n      <td>C03095174_Isomer1-1</td>\n      <td>GPR40</td>\n      <td>8177</td>\n      <td>6</td>\n      <td>-11.17170</td>\n      <td>-0.37239</td>\n      <td>-1.1571</td>\n      <td>-2.53833</td>\n      <td>-11.1717</td>\n      <td>-4.5256</td>\n      <td>-0.479901</td>\n      <td>-0</td>\n      <td>-3.22389</td>\n      <td>-45.9457</td>\n      <td>-6.19778</td>\n      <td>0.368657</td>\n      <td>-0.0840014</td>\n      <td>-94.3056</td>\n      <td>-52.1435</td>\n      <td>18.5623</td>\n      <td>126</td>\n      <td>47</td>\n      <td>0</td>\n      <td>11.220968</td>\n      <td>7.912696</td>\n      <td>NaN</td>\n      <td>0.0</td>\n      <td>0</td>\n      <td>244</td>\n      <td>0.000000</td>\n      <td>0.000114</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>TAK-875_Isomer2</td>\n      <td>&lt;rdkit.Chem.rdchem.Mol object at 0x15b714e40&gt;</td>\n      <td>1</td>\n      <td>GPR40_chembl19_set_active_sc.smi</td>\n      <td>246</td>\n      <td>53161</td>\n      <td>0</td>\n      <td>S-OPLS</td>\n      <td>32.6087</td>\n      <td>1</td>\n      <td>TAK-875_Isomer2-1</td>\n      <td>GPR40</td>\n      <td>245</td>\n      <td>11</td>\n      <td>-11.10010</td>\n      <td>-0.300002</td>\n      <td>-0.999675</td>\n      <td>-2.40735</td>\n      <td>-11.1001</td>\n      <td>-5.53916</td>\n      <td>-0.524851</td>\n      <td>-0</td>\n      <td>-1.01411</td>\n      <td>-46.0319</td>\n      <td>-15.4161</td>\n      <td>0.675266</td>\n      <td>-0.0832139</td>\n      <td>-109.415</td>\n      <td>-61.448</td>\n      <td>11.2322</td>\n      <td>96</td>\n      <td>372</td>\n      <td>0</td>\n      <td>9.807528</td>\n      <td>8.486209</td>\n      <td>NaN</td>\n      <td>3.0</td>\n      <td>1</td>\n      <td>244</td>\n      <td>0.004098</td>\n      <td>0.000228</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>C13171061_Isomer1</td>\n      <td>&lt;rdkit.Chem.rdchem. ...
#      'execution_count': 19}],
#    'source': 'all_data = calculate_enrichment_parameters(all_data)\nall_data',
#    'id': '491eeee8'},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.436881',
#      'end_time': '2024-02-19T22:17:45.450047',
#      'duration': 0.013166,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.447400Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.447514Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.449158Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.448923Z'}},
#    'outputs': [],
#    'source': 'total_e_thresholds = [None, 4, 4.5, 5.0, 5.5, 6.0, 7.0, 7.5, 8.0]',
#    'id': 'a7b0d82d'},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.458949',
#      'end_time': '2024-02-19T22:17:45.474163',
#      'duration': 0.015214,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.470764Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.470889Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.473370Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.473139Z'}},
#    'outputs': [],
#    'source': 'def logauc_by_strain(df, a=1e-3, total_e_threshold=None):\n    # Filter dataframe based on \'Total_E\' threshold if provided\n    if total_e_threshold is not None:\n        df = df[df["Total_E"] <= total_e_threshold]\n\n    # Invert scores since lower scores indicate positive class\n    y_scores_inverted = -df["r_i_docking_score"]\n\n    # Calculate FPR, TPR, and thresholds using sklearn\n    fpr, tpr, _ = roc_curve(df["Activity"], y_scores_inverted)\n\n    # Select the thresholds that result in FPR >= a for log scale plotting\n    valid_indices = np.where(fpr >= a)\n    fpr_valid = fpr[valid_indices]\n    tpr_valid = tpr[valid_indices]\n\n    # Calculate log of FPR for valid indices\n    log_fpr_valid = np.log10(fpr_valid)\n\n    # Calculate the AUC for the valid range\n    linlog_auc = auc(log_fpr_valid, tpr_valid)\n\n    ### NOTE TIMES 10 NOTE ###\n    log_auc = (linlog_auc / -np.log10(a)) * 10\n\n    return log_auc',
#    'id': 'd895e153'},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.488509',
#      'end_time': '2024-02-19T22:17:45.506313',
#      'duration': 0.017804,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.502745Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.502905Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.505464Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.505182Z'}},
#    'outputs': [],
#    'source': 'def plot_log_aucs(data, thresholds, title_suffix):\n    # Calculate log_auc for each threshold and plot\n    log_aucs = [logauc_by_strain(data, total_e_threshold=t) for t in thresholds]\n    \n    # Create labels for the x-axis\n    x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n    \n    plt.bar(range(len(thresholds)), log_aucs, tick_label=x_labels)\n    plt.title(f"Linear Log10 AUC by Strain Energy Cutoff ({title_suffix})")\n    plt.xlabel("Strain Energy Cutoff")\n    plt.ylabel("Linear Log10 AUC (x10)")\n    plt.show()',
#    'id': '41ad987c'},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.520672',
#      'end_time': '2024-02-19T22:17:45.643626',
#      'duration': 0.122954,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.541499Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.541623Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.642558Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.642171Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_log_aucs(all_data, total_e_thresholds, title_suffix)',
#    'id': '0deb7607'},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.655974',
#      'end_time': '2024-02-19T22:17:45.773840',
#      'duration': 0.117866,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.668917Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.669044Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.772862Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.772495Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'def plot_delta_log_aucs(data, thresholds, title_suffix):\n  # Calculate log_auc for \'None\' threshold\n  none_log_auc = logauc_by_strain(data, total_e_threshold=None)\n  \n  # Calculate delta log_auc for each threshold and plot\n  delta_log_aucs = [logauc_by_strain(data, total_e_threshold=t) - none_log_auc for t in thresholds]\n  \n  # Create labels for the x-axis\n  x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n  \n  plt.bar(range(len(thresholds)), delta_log_aucs, tick_label=x_labels)\n  plt.title(f"Delta Linear Log10 AUC by Strain Energy Cutoff ({title_suffix})")\n  plt.xlabel("Strain Energy Cutoff")\n  plt.ylabel("Delta Linear Log10 AUC (x10)")\n  plt.show()\n\nplot_delta_log_aucs(all_data, total_e_thresholds, title_suffix)',
#    'id': '0dce9015'},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.788496',
#      'end_time': '2024-02-19T22:17:45.836326',
#      'duration': 0.04783,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.802396Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.802536Z',
#      'iopub.status.idle': '2024-02-19T22:17:45.835229Z',
#      'shell.execute_reply': '2024-02-19T22:17:45.834942Z'}},
#    'outputs': [],
#    'source': 'def write_log_aucs(data, thresholds, title_suffix):\n    # Calculate log_auc for each threshold\n    log_aucs = [logauc_by_strain(data, total_e_threshold=t) for t in thresholds]\n\n    delta_log_aucs = [0] + [log_aucs[i] - log_aucs[0] for i in range(1, len(log_aucs))]\n\n    #print(f"Delta LogAUCs for {title_suffix}: {delta_log_aucs}")\n\n    # Create labels for the x-axis\n    x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n    \n    # Create a dataframe to hold the data\n    df = pd.DataFrame({\n        "Protein": title_suffix,\n        "Strain Energy Cutoff": x_labels,\n        "Linear Log10 AUC (x10)": log_aucs,\n        "Delta Linear Log10 AUC (x10)": delta_log_aucs\n    })\n    \n    # Write the dataframe to a CSV file\n    df.to_csv(f"strain_log_aucs_{title_suffix}.csv", index=False)\n\nwrite_log_aucs(all_data, total_e_thresholds, title_suffix)',
#    'id': '4377c77a'},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:45.849629',
#      'end_time': '2024-02-19T22:17:46.009093',
#      'duration': 0.159464,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:45.861842Z',
#      'iopub.execute_input': '2024-02-19T22:17:45.861996Z',
#      'iopub.status.idle': '2024-02-19T22:17:46.008033Z',
#      'shell.execute_reply': '2024-02-19T22:17:46.007719Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'def enrichment_metrics_by_strain(df, total_e_threshold=None):\n\n    if total_e_threshold is not None:\n        df = df[df["Total_E"] <= total_e_threshold]\n\n    df = calculate_enrichment_parameters(df).copy()\n\n    closest_to_one_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.01).abs().argsort()[:1]\n    ]\n\n    ef1 = (\n        closest_to_one_percent["Cumulative_Actives"].values[0]\n        / closest_to_one_percent["Total_Actives"].values[0]\n    ) * 100\n\n    closest_to_five_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.05).abs().argsort()[:1]\n    ]\n    ef5 = (\n        closest_to_five_percent["Cumulative_Actives"].values[0]\n        / closest_to_five_percent["Total_Actives"].values[0]) * 100\n\n    # print(df.shape)\n\n    # print(\n    #     f"1% Closest Cumulative_Actives: {closest_to_one_percent[\'Cumulative_Actives\'].values[0]}"\n    # )\n    # print(\n    #     f"1% Closest Total_Actives: {closest_to_one_percent[\'Total_Actives\'].values[0]}"\n    # )\n    # print(\n    #     f"5% Closest Cumulative_Actives: {closest_to_five_percent[\'Cumulative_Actives\'].values[0]}"\n    # )\n    # print(\n    #     f"5% Closest Total_Actives: {closest_to_five_percent[\'Total_Actives\'].values[0]}"\n    # )\n\n    return ef1, ef5\n\n\ndef bar_plot_enrichment_by_strain(data, thresholds, title_suffix):\n    # Calculate enrichment for each threshold\n    ef1s, ef5s = zip(*[enrichment_metrics_by_strain(data, total_e_threshold=t) for t in thresholds])\n\n    # print(f"EF1% for {title_suffix}: {ef1s}")\n    # print(f"EF5% for {title_suffix}: {ef5s}")\n\n    # Create labels for the x-axis\n    x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n\n    # Create an array with the positions of each bar on the x axis\n    x = np.arange(len(x_labels))\n\n    # Set the width of the bars\n    bar_width = 0.35\n\n    plt.bar(x - bar_width/2, ef1s, bar_width, label="EF1%")\n    plt.bar(x + bar_width/2, ef5s, bar_width, label="EF5%")\n    plt.title(f"Enrichment Factors by Strain Energy Cutoff ({title_suffix})")\n    plt.xlabel("Strain Energy Cutoff")\n    plt.ylabel("Enrichment Factor (%)")\n    plt.xticks(x, x_labels)  # Set the position and labels of the xticks\n    plt.legend()\n    plt.show()\n\nbar_plot_enrichment_by_strain(all_data, total_e_thresholds, title_suffix)',
#    'id': '59643d4d'},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:46.024118',
#      'end_time': '2024-02-19T22:17:46.321633',
#      'duration': 0.297515,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:46.034988Z',
#      'iopub.execute_input': '2024-02-19T22:17:46.035119Z',
#      'iopub.status.idle': '2024-02-19T22:17:46.320584Z',
#      'shell.execute_reply': '2024-02-19T22:17:46.320270Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': '/var/folders/2c/b9b_8fbs13j5zcz4wv9bqqjm0000gn/T/ipykernel_47946/2506411786.py:53: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.\n  cmap = cm.get_cmap(\n'},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 800x800 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'def plot_enrichment_curve_by_strain(df, total_e_threshold=None, ax=None, color=\'blue\'):\n\n    if total_e_threshold is not None:\n        df = df[df["Total_E"] <= total_e_threshold]\n\n    df = calculate_enrichment_parameters(df).copy()\n\n    enrichment_auc = auc(df["Percentage_Screened"], df["Fraction_Actives"])\n\n    closest_to_one_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.01).abs().argsort()[:1]\n    ]\n\n    ef1 = (\n        closest_to_one_percent["Cumulative_Actives"].values[0]\n        / closest_to_one_percent["Total_Actives"].values[0]\n    ) * 100\n\n    closest_to_five_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.05).abs().argsort()[:1]\n    ]\n    ef5 = (\n        closest_to_five_percent["Cumulative_Actives"].values[0]\n        / closest_to_five_percent["Total_Actives"].values[0]\n    ) * 100\n\n    # Plot the enrichment curve\n    ax.plot(\n        df["Percentage_Screened"] * 100,\n        df["Fraction_Actives"] * 100,\n        label="Threshold: {}\\nEnrichment AUC = {:.2f}\\n(EF1% = {:.1f}%)\\n(EF5% = {:.0f}%)".format(\n            total_e_threshold if total_e_threshold is not None else \'N/A\',\n            enrichment_auc, ef1, ef5\n            ),\n        color=color\n        )\n\n    # # Add axis labels and title\n    # plt.xlabel("Compounds Screened (%)")\n    # plt.ylabel("Percent of Identified Actives (%)")\n    # plt.title(f"Enrichment Curve ({title_suffix})")\n\n    ax.legend()\n\n\ndef plot_enrichment_all_thresholds(data, thresholds, title_suffix):\n    # Create a single plot\n    fig, ax = plt.subplots(\n        figsize=(8, 8)\n        )\n\n    # Define a colormap\n    cmap = cm.get_cmap(\n        "viridis", len(thresholds) - 1\n    )  # Subtract 1 because the first color is manually set\n\n    # Plot semi-log ROC curve for each threshold\n    for i, t in enumerate(thresholds):\n        # Filter dataframe based on \'Total_E\' threshold\n        df_filtered = data if t is None else data[data["Total_E"] <= t]\n\n        # Set a distinct color for the first threshold\n        color = (\n            "red" if t is None else cmap(i - 1)\n        )  # Subtract 1 because the first color is manually set\n\n        # Call the function with the filtered data\n        plot_enrichment_curve_by_strain(df_filtered, total_e_threshold=t, ax=ax, color=color)\n\n    ax.set_title(f"Enrichment Curves by Strain Energy Thresholds ({title_suffix})")\n    ax.set_xlabel("Percent Screened")\n    ax.set_ylabel("Percent Identified Actives")\n\n    plt.tight_layout()\n    plt.show()\n\nplot = plot_enrichment_all_thresholds(all_data, total_e_thresholds, title_suffix)',
#    'id': 'e916b0a4'},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:46.337895',
#      'end_time': '2024-02-19T22:17:46.419666',
#      'duration': 0.081771,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:46.354737Z',
#      'iopub.execute_input': '2024-02-19T22:17:46.354866Z',
#      'iopub.status.idle': '2024-02-19T22:17:46.418765Z',
#      'shell.execute_reply': '2024-02-19T22:17:46.418490Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Writing CSV to strain_enrichment_metrics_GPR40.csv\nCSV writing complete.\nCSV writing complete.\n'}],
#    'source': 'def write_enrichment_metrics(data, thresholds, title_suffix):\n    # Calculate enrichment for each threshold\n    ef1s, ef5s = zip(*[enrichment_metrics_by_strain(data, total_e_threshold=t) for t in thresholds])\n\n    # Create labels for the x-axis\n    x_labels = [str(t) if t is not None else \'No Cutoff\' for t in thresholds]\n\n    # Create a dataframe to hold the data\n    df = pd.DataFrame({\n        "Protein": title_suffix,\n        "Strain Energy Cutoff": x_labels,\n        "EF1%": ef1s,\n        "EF5%": ef5s\n    })\n\n    print(f"Writing CSV to strain_enrichment_metrics_{title_suffix}.csv")\n    df.to_csv(f"./papermill/csv/strain_enrichment_metrics_{title_suffix}.csv", index=False)\n    print("CSV writing complete.")\n\n    try:\n        df.to_csv(\n            f"./papermill/csv/strain_enrichment_metrics_{title_suffix}.csv", index=False\n        )\n        print("CSV writing complete.")\n    except Exception as e:\n        print(f"Failed to write CSV: {e}")\n\nwrite_enrichment_metrics(all_data, total_e_thresholds, title_suffix)',
#    'id': '54e07d6f'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:46.439454',
#      'end_time': '2024-02-19T22:17:46.457280',
#      'duration': 0.017826,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:46.453196Z',
#      'iopub.execute_input': '2024-02-19T22:17:46.453327Z',
#      'iopub.status.idle': '2024-02-19T22:17:46.456432Z',
#      'shell.execute_reply': '2024-02-19T22:17:46.456117Z'}},
#    'outputs': [],
#    'source': 'def plot_semi_log_roc(df, a=1e-3, total_e_threshold=None, ax=None, color=\'blue\'):\n  # Filter dataframe based on \'Total_E\' threshold if provided\n  if total_e_threshold is not None:\n    df = df[df["Total_E"] <= total_e_threshold]\n\n  # Invert scores since lower scores indicate positive class\n  y_scores_inverted = -df["r_i_docking_score"]\n\n  # Calculate FPR, TPR, and thresholds using sklearn\n  fpr, tpr, _ = roc_curve(df["Activity"], y_scores_inverted)\n\n  # Select the thresholds that result in FPR >= a for log scale plotting\n  valid_indices = np.where(fpr >= a)\n  fpr_valid = fpr[valid_indices]\n  tpr_valid = tpr[valid_indices]\n\n  # Calculate log of FPR for valid indices\n  log_fpr_valid = np.log10(fpr_valid)\n\n  # Calculate LogAUC\n  log_auc = (auc(log_fpr_valid, tpr_valid) / -np.log10(a)) * 10\n\n  # Count the number of rows with Activity = 1 and the total number of rows\n  activity_1_count = df[df["Activity"] == 1].shape[0]\n  total_count = df.shape[0]\n\n  # Plot semi-log ROC curve\n  ax.plot(\n    log_fpr_valid,\n    tpr_valid,\n    label=f"Threshold: {total_e_threshold if total_e_threshold is not None else \'N/A\'}, LogAUC: {log_auc:.2f}, Actives: {activity_1_count}, Total count: {total_count}",\n    color=color\n  )\n  ax.legend()\n',
#    'id': 'bfbd28b8'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:46.472020',
#      'end_time': '2024-02-19T22:17:46.491212',
#      'duration': 0.019192,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:46.486984Z',
#      'iopub.execute_input': '2024-02-19T22:17:46.487111Z',
#      'iopub.status.idle': '2024-02-19T22:17:46.490285Z',
#      'shell.execute_reply': '2024-02-19T22:17:46.490005Z'}},
#    'outputs': [],
#    'source': 'def plot_all_thresholds(data, thresholds, title_suffix):\n    # Create a single plot\n    fig, ax = plt.subplots(figsize=(10, 10))\n\n    # Define a colormap\n    cmap = cm.get_cmap(\'viridis\', len(thresholds) - 1)  # Subtract 1 because the first color is manually set\n\n    # Plot semi-log ROC curve for each threshold\n    for i, t in enumerate(thresholds):\n        # Filter dataframe based on \'Total_E\' threshold\n        df_filtered = data if t is None else data[data["Total_E"] <= t]\n\n        # Set a distinct color for the first threshold\n        color = \'red\' if t is None else cmap(i - 1)  # Subtract 1 because the first color is manually set\n\n        # Call the function with the filtered data\n        plot_semi_log_roc(df_filtered, total_e_threshold=t, ax=ax, color=color)\n\n    ax.set_title(f"Strain Energy Thresholds ({title_suffix})")\n    ax.set_xlabel("log(FPR)")\n    ax.set_ylabel("TPR")\n\n    plt.tight_layout()\n    plt.show()',
#    'id': 'ee64585c'},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:17:46.502068',
#      'end_time': '2024-02-19T22:17:46.739103',
#      'duration': 0.237035,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:17:46.525487Z',
#      'iopub.execute_input': '2024-02-19T22:17:46.525643Z',
#      'iopub.status.idle': '2024-02-19T22:17:46.738080Z',
#      'shell.execute_reply': '2024-02-19T22:17:46.737745Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
# ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Molecule_Name</th>\n      <th>Mol</th>\n      <th>Activity</th>\n      <th>s_m_source_file</th>\n      <th>i_m_source_file_index</th>\n      <th>i_lp_mmshare_version</th>\n      <th>i_f3d_flags</th>\n      <th>s_lp_Force_Field</th>\n      <th>r_lp_Energy</th>\n      <th>b_lp_Chiralities_Consistent</th>\n      <th>s_lp_Variant</th>\n      <th>s_i_glide_gridfile</th>\n      <th>i_i_glide_lignum</th>\n      <th>i_i_glide_rotatable_bonds</th>\n      <th>r_i_docking_score</th>\n      <th>r_i_glide_ligand_efficiency</th>\n      <th>r_i_glide_ligand_efficiency_sa</th>\n      <th>r_i_glide_ligand_efficiency_ln</th>\n      <th>r_i_glide_gscore</th>\n      <th>r_i_glide_lipo</th>\n      <th>r_i_glide_hbond</th>\n      <th>r_i_glide_metal</th>\n      <th>r_i_glide_rewards</th>\n      <th>r_i_glide_evdw</th>\n      <th>r_i_glide_ecoul</th>\n      <th>r_i_glide_erotb</th>\n      <th>r_i_glide_esite</th>\n      <th>r_i_glide_emodel</th>\n      <th>r_i_glide_energy</th>\n      <th>r_i_glide_einternal</th>\n      <th>i_i_glide_confnum</th>\n      <th>i_i_glide_posenum</th>\n      <th>r_i_glide_eff_state_penalty</th>\n      <th>Total_E</th>\n      <th>Lower_Bound</th>\n      <th>Upper_Bound</th>\n      <th>Num_Torsion_Patterns</th>\n      <th>Cumulative_Actives</th>\n      <th>Total_Actives</th>\n      <th>Fraction_Actives</th>\n      <th>Percentage_Screened</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>C03095174_Isomer1</td>\n      <td>&lt;rdkit.Chem.rdchem.Mol object at 0x15b7cc430&gt;</td>\n      <td>0</td>\n      <td>GPR40_chembl19_set_decoy_sc.smi</td>\n      <td>8178</td>\n      <td>53161</td>\n      <td>0</td>\n      <td>S-OPLS</td>\n      <td>57.1172</td>\n      <td>1</td>\n      <td>C03095174_Isomer1-1</td>\n      <td>GPR40</td>\n      <td>8177</td>\n      <td>6</td>\n      <td>-11.17170</td>\n      <td>-0.37239</td>\n      <td>-1.1571</td>\n      <td>-2.53833</td>\n      <td>-11.1717</td>\n      <td>-4.5256</td>\n      <td>-0.479901</td>\n      <td>-0</td>\n      <td>-3.22389</td>\n      <td>-45.9457</td>\n      <td>-6.19778</td>\n      <td>0.368657</td>\n      <td>-0.0840014</td>\n      <td>-94.3056</td>\n      <td>-52.1435</td>\n      <td>18.5623</td>\n      <td>126</td>\n      <td>47</td>\n      <td>0</td>\n      <td>11.220968</td>\n      <td>7.912696</td>\n      <td>NaN</td>\n      <td>0.0</td>\n      <td>0</td>\n      <td>244</td>\n      <td>0.000000</td>\n      <td>0.000114</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>TAK-875_Isomer2</td>\n      <td>&lt;rdkit.Chem.rdchem.Mol object at 0x15b714e40&gt;</td>\n      <td>1</td>\n      <td>GPR40_chembl19_set_active_sc.smi</td>\n      <td>246</td>\n      <td>53161</td>\n      <td>0</td>\n      <td>S-OPLS</td>\n      <td>32.6087</td>\n      <td>1</td>\n      <td>TAK-875_Isomer2-1</td>\n      <td>GPR40</td>\n      <td>245</td>\n      <td>11</td>\n      <td>-11.10010</td>\n      <td>-0.300002</td>\n      <td>-0.999675</td>\n      <td>-2.40735</td>\n      <td>-11.1001</td>\n      <td>-5.53916</td>\n      <td>-0.524851</td>\n      <td>-0</td>\n      <td>-1.01411</td>\n      <td>-46.0319</td>\n      <td>-15.4161</td>\n      <td>0.675266</td>\n      <td>-0.0832139</td>\n      <td>-109.415</td>\n      <td>-61.448</td>\n      <td>11.2322</td>\n      <td>96</td>\n      <td>372</td>\n      <td>0</td>\n      <td>9.807528</td>\n      <td>8.486209</td>\n      <td>NaN</td>\n      <td>3.0</td>\n      <td>1</td>\n      <td>244</td>\n      <td>0.004098</td>\n      <td>0.000228</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>C13171061_Isomer1</td>\n      <td>&lt;rdkit.Chem.rdchem. ...
#    'source': 'all_pareto_ranks_indices = np.concatenate(pareto_ranks_indices)\ndisplay(data.iloc[all_pareto_ranks_indices])',
#    'id': '5ebc173a'},
#   {'cell_type': 'code',
#    'execution_count': 45,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:18:15.144768',
#      'end_time': '2024-02-19T22:18:15.178385',
#      'duration': 0.033617,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:18:15.175054Z',
#      'iopub.execute_input': '2024-02-19T22:18:15.175203Z',
#      'iopub.status.idle': '2024-02-19T22:18:15.177502Z',
#      'shell.execute_reply': '2024-02-19T22:18:15.177260Z'}},
#    'outputs': [],
#    'source': 'pareto_front_df = data.iloc[all_pareto_ranks_indices]',
#    'id': 'b7dbe69d'},
#   {'cell_type': 'code',
#    'execution_count': 46,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:18:15.191815',
#      'end_time': '2024-02-19T22:18:15.361262',
#      'duration': 0.169447,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:18:15.205763Z',
#      'iopub.execute_input': '2024-02-19T22:18:15.205897Z',
#      'iopub.status.idle': '2024-02-19T22:18:15.359309Z',
#      'shell.execute_reply': '2024-02-19T22:18:15.357115Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_density(pareto_front_df, title_suffix)',
#    'id': '4e411d13'},
#   {'cell_type': 'code',
#    'execution_count': 47,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:18:15.385513',
#      'end_time': '2024-02-19T22:18:15.578011',
#      'duration': 0.192498,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:18:15.414034Z',
#      'iopub.execute_input': '2024-02-19T22:18:15.414311Z',
#      'iopub.status.idle': '2024-02-19T22:18:15.575931Z',
#      'shell.execute_reply': '2024-02-19T22:18:15.574751Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_density_strain(pareto_front_df, title_suffix)',
#    'id': '84fe0d4e'},
#   {'cell_type': 'code',
#    'execution_count': 48,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:18:15.606686',
#      'end_time': '2024-02-19T22:18:15.643071',
#      'duration': 0.036385,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:18:15.632402Z',
#      'iopub.execute_input': '2024-02-19T22:18:15.632719Z',
#      'iopub.status.idle': '2024-02-19T22:18:15.639937Z',
#      'shell.execute_reply': '2024-02-19T22:18:15.639316Z'}},
#    'outputs': [],
#    'source': 'pareto_front_df = calculate_enrichment_parameters(pareto_front_df)',
#    'id': '4f6d6558'},
#   {'cell_type': 'code',
#    'execution_count': 49,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:18:15.664442',
#      'end_time': '2024-02-19T22:18:15.692854',
#      'duration': 0.028412,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:18:15.682808Z',
#      'iopub.execute_input': '2024-02-19T22:18:15.683094Z',
#      'iopub.status.idle': '2024-02-19T22:18:15.690624Z',
#      'shell.execute_reply': '2024-02-19T22:18:15.690007Z'}},
#    'outputs': [],
#    'source': 'def plot_enrichment_curve_classifier(df, title_suffix):\n    """\n    Plots the enrichment curve for a dataframe, including the performance of a random classifier.\n\n    Parameters:\n    df (pandas.DataFrame): The dataframe to plot the enrichment curve for.\n    title_suffix (str): The suffix to add to the title of the plot.\n\n    Returns:\n    None\n    """\n    # Calculate the Enrichment AUC\n    enrichment_auc = auc(df["Percentage_Screened"], df["Fraction_Actives"])\n\n    # Calculate the enrichment at the closest value to 1%\n    # Subtract 0.01 (1%) from the \'Percentage_Screened\' column and find the absolute value\n    # (df[\'Percentage_Screened\'] - 0.01).abs()\n    # Sort the resulting series and take the first index (smallest difference)\n    # (df[\'Percentage_Screened\'] - 0.01).abs().argsort()[:1]\n    # Use the index to get the row from the dataframe\n    closest_to_one_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.01).abs().argsort()[:1]\n    ]\n    # df["Some_Column"].values[0] gets the value of the first row of "Some_Column"\n    # It would return a pd.Series without: .values[0]\n    enrichment_at_one_percent = (\n        closest_to_one_percent["Cumulative_Actives"].values[0]\n        / closest_to_one_percent["Total_Actives"].values[0]\n    )\n\n    closest_to_five_percent = df.iloc[\n        (df["Percentage_Screened"] - 0.05).abs().argsort()[:1]\n    ]\n    # df["Some_Column"].values[0] gets the value of the first row of "Some_Column"\n    # It would return a pd.Series without: .values[0]\n    enrichment_at_five_percent = (\n        closest_to_five_percent["Cumulative_Actives"].values[0]\n        / closest_to_five_percent["Total_Actives"].values[0]\n    )\n\n    # Plot the enrichment curve\n    plt.plot(\n        df["Percentage_Screened"] * 100,\n        df["Fraction_Actives"] * 100,\n        label="Enrichment AUC = {:.2f}\\n(EF1% = {:.1f}%)\\n(EF5% = {:.0f}%)".format(\n            enrichment_auc,\n            enrichment_at_one_percent * 100,\n            enrichment_at_five_percent * 100,\n        ),\n    )\n\n    #   # Plot the enrichment at 1%\n    #   plt.scatter(\n    #   1,\n    #   enrichment_at_one_percent * 100,\n    #   s=0,\n    #   color=\'black\',\n    #   label="Enrichment (%) at 1% = {:.2f}".format(enrichment_at_one_percent*100),\n    # )\n\n    # Calculate and plot the performance of a random classifier\n    overall_fraction_actives = df["Fraction_Actives"].iloc[\n        -1\n    ]  # Assuming the last point represents the overall fraction\n    plt.plot(\n        [0, 100],\n        [0, overall_fraction_actives * 100],\n        label="Random Classifier",\n        linestyle="--",\n        color="grey",\n    )\n\n    # Add axis labels and title\n    plt.xlabel("Compounds Screened (%)")\n    plt.ylabel("Percent of Identified Actives (%)")\n    plt.title(f"Enrichment Curve ({title_suffix})")\n\n    plt.legend()\n    plt.show()\n',
#    'id': 'e3fc3c34'},
#   {'cell_type': 'code',
#    'execution_count': 50,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:18:15.710339',
#      'end_time': '2024-02-19T22:18:15.743530',
#      'duration': 0.033191,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:18:15.736410Z',
#      'iopub.execute_input': '2024-02-19T22:18:15.736565Z',
#      'iopub.status.idle': '2024-02-19T22:18:15.742520Z',
#      'shell.execute_reply': '2024-02-19T22:18:15.742257Z'}},
#    'outputs': [],
#    'source': 'threshold4 = all_data[all_data["Total_E"] <= 4]\nthreshold4 = calculate_enrichment_parameters(threshold4)',
#    'id': 'c0dc90ea'},
#   {'cell_type': 'code',
#    'execution_count': 51,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:18:15.758571',
#      'end_time': '2024-02-19T22:18:16.121610',
#      'duration': 0.363039,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-19T22:18:15.773932Z',
#      'iopub.execute_input': '2024-02-19T22:18:15.774081Z',
#      'iopub.status.idle': '2024-02-19T22:18:16.120305Z',
#      'shell.execute_reply': '2024-02-19T22:18:16.119895Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '<Figure size 640x480 with 1 Axes>',
#       'image/png': '...'}}],
#    'source': 'plot_enrichment_curve_classifier(all_data, "GPR40 Baseline")\nplot_enrichment_curve_classifier(threshold4, "GPR40 Total_E <= 4")\nplot_enrichment_curve_classifier(pareto_front_df, "GPR40 Pareto Rank 20")',
#    'id': '4d8d0ee8'},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-19T22:18:16.133509',
#      'end_time': '2024-02-19T22:18:16.147525',
#      'duration': 0.014016,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '',
#    'id': '498102db'}],
#  'metadata': {'kernelspec': {'display_name': 'analytics_env',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.5',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {'title_suffix': 'GPR40',
#     'file_path_sdf_active': './GPR40/docking/GPR40_active_docking_lib_sorted.sdf',
#     'file_path_sdf_decoy': './GPR40/docking/GPR40_decoy_docking_lib_sorted.sdf',
#     'file_path_strain_active': './GPR40/strain/GPR40_active_docking_lib_sorted.csv',
#     'file_path_strain_decoy': './GPR40/strain/GPR40_decoy_docking_lib_sorted.csv'},
#    'environment_variables': {},
#    'version': '2.5.0',
#    'input_path': 'gpcr_papermill.ipynb',
#    'output_path': './papermill/notebooks/gpcr_papermill_output_GPR40.ipynb',
#    'start_time': '2024-02-19T22:17:30.073481',
#    'end_time': '2024-02-19T22:18:16.783843',
#    'duration': 46.710362,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
import os
import pprint

# Get a list of all subfolders in the current working directory that start with a capital letter
subfolders = [f.name for f in os.scandir(".") if f.is_dir() and f.name[0].isupper()]

parameters_list = []

# Create a parameters dictionary for each subfolder
for subfolder in subfolders:
    parameters = {
        "title_suffix": subfolder,
        "file_path_sdf_active": f"./{subfolder}/docking/{subfolder}_active_docking_lib_sorted.sdf",
        "file_path_sdf_decoy": f"./{subfolder}/docking/{subfolder}_decoy_docking_lib_sorted.sdf",
        "file_path_strain_active": f"./{subfolder}/strain/{subfolder}_active_docking_lib_sorted.csv",
        "file_path_strain_decoy": f"./{subfolder}/strain/{subfolder}_decoy_docking_lib_sorted.csv",
    }

    output_notebook = f"./papermill/notebooks/gpcr_papermill_output_{parameters['title_suffix']}.ipynb"

    parameters_list.append(
        {
            "output_notebook": output_notebook,
            "parameters": parameters,
        }
    )

# pprint.pprint(parameters_list)

# Execute the notebook for each set of parameters
for params in parameters_list:
    pm.execute_notebook(
        "gpcr_papermill.ipynb",
        params["output_notebook"],
        parameters=params["parameters"],
    )
# Out:
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/52 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
